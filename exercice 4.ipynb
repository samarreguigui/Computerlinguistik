# %%
import math
from collections import defaultdict

class CRFTagger:
    def __init__(self):
        # Gewichtsvektor
        self.weights = defaultdict(float)
        self.tagset = set()
        learning_rate = 0.01
        self.learning_rate = learning_rate


    def read_data(self, path):
        """Liest Trainingsdaten und fügt START und END Tokens ein."""
        data = []
        sentence = []
        with open(path, encoding="utf-8") as f:
            for line in f:
                line = line.strip()
                if not line:
                    if sentence:
                        sentence = [("< >", "<//s>")] + sentence + [("< >", "<//s>")]
                        data.append(sentence)
                        sentence = []
                    continue
                word, tag = line.split()
                sentence.append((word, tag))
                self.tagset.add(tag)
        if sentence:
            sentence = [("< >", "<//s>")] + sentence + [("< >", "<//s>")]
            data.append(sentence)
        return data

    def lex_features(self, tag, words, i):
        """Lexikalische Merkmale für das Wort an Position i."""
        word = words[i]
        feats = []

        # (1) Wort + Tag
        feats.append(f"WT-{word}+{tag}")

        # (2) Wort-Suffix + Tag (für Suffixlängen 2–5)
        for l in range(2, 6):
            if len(word) >= l:
                suffix = word[-l:]
                feats.append(f"ST-{suffix}+{tag}")

        # (3) Wortform (Shape) + Tag
        shape = ''.join(
            'A' if c.isupper() else 'a' if c.islower() else '0'
            for c in word
        )
        feats.append(f"SH-{shape}+{tag}")

        return feats

    def context_features(self, prevtag, tag, words, i):
        """Kontextmerkmale abhängig vom vorherigen Wort und Tag."""
        feats = []

        # (4) Vorheriges Wort + aktuelles Tag
        prev_word = words[i - 1] if i > 0 else "<//s>"
        feats.append(f"PW-{prev_word}+{tag}")

        # (5) Vorheriges Tag + aktuelles Tag
        feats.append(f"PT-{prevtag}+{tag}")

        return feats




    def lex_score(self, tag, words, i):
        """Berechnet lexikalischen Score: Summe aller Gewichte aktiver lexikalischer Merkmale."""
        score = 0.0
        for feat in self.lex_features(tag, words, i):
            score += self.weights[feat]      # Gewicht * 1, weil Merkmal aktiv
        return score

    def context_score(self, prevtag, tag, words, i):
        """Berechnet Kontextscore: Summe aller Gewichte aktiver Kontextmerkmale."""
        score = 0.0
        for feat in self.context_features(prevtag, tag, words, i):
            score += self.weights[feat]      # Gewicht * 1, weil Merkmal aktiv
        return score

    def compute_score(self, prevtag, tag, words, i):
        """Kombiniert lexikalischen und Kontextscore zu einem Gesamtscore."""
        return self.lex_score(tag, words, i) + self.context_score(prevtag, tag, words, i)

    def forward(self, words):
        """Berechnet Forward-Scores α[i][tag] entsprechend Folie."""
        alpha = [defaultdict(float)]
        alpha[0]["START"] = 0.0  # log(1)

        for i in range(1, len(words)):
            alpha.append(defaultdict(float))

            # Bestimme Tag-Liste (letzte Position = END)
            tags = self.tagset if i < len(words) - 1 else ["//s"]

            for tag in tags:
                lexical_score = self.lex_score(tag, words, i)
                total_scores = []

                for prev_tag, prev_score in alpha[i - 1].items():
                    count_score = prev_score + self.context_score(prev_tag, tag, words, i) + lexical_score
                    total_scores.append(count_score)

                # Log-Summe zur Stabilität (Unterlauf vermeiden)
                m = max(total_scores)
                alpha[i][tag] = m + math.log(sum(math.exp(s - m) for s in total_scores))

        return alpha

    def backward(self, words):
        """Berechnet Backward-Scores β[i][tag] im Log-Raum."""
        n = len(words)
        beta = [defaultdict(float) for _ in range(n)]
        beta[-1]["END"] = 0.0  # log(1)

        for i in range(n - 2, -1, -1):
            for tag in self.tagset if i > 0 else ["START"]:
                total_scores = []
                for next_tag, next_score in beta[i + 1].items():
                    count_score = (
                        next_score
                        + self.context_score(tag, next_tag, words, i + 1)
                        + self.lex_score(next_tag, words, i + 1)
                    )
                    total_scores.append(count_score)

                m = max(total_scores)
                beta[i][tag] = m + math.log(sum(math.exp(s - m) for s in total_scores))

        return beta

    def observed_freq(self, words, tags):
        """Zählt beobachtete Merkmalsfrequenzen im Trainingssatz."""
        freq = defaultdict(float)
        for i in range(1, len(words)):
            tag = tags[i]
            prevtag = tags[i - 1]

            # lexikalische Merkmale
            for f in self.lex_features(tag, words, i):
                freq[f] += 1.0

            # kontextuelle Merkmale
            for f in self.context_features(prevtag, tag, words, i):
                freq[f] += 1.0
        return freq
    def expected_freq(self, words):
        """Berechnet erwartete Merkmalsfrequenzen aus Forward/Backward."""
        freq = defaultdict(float)
        alpha = self.forward(words)
        beta = self.backward(words)

        n = len(words)
        # Normierungskonstante Z = log-sum-exp über letzte α-Werte
        Z = max(alpha[-1].values())
        Z += math.log(sum(math.exp(v - Z) for v in alpha[-1].values()))

        for i in range(1, n):
            for tag in self.tagset:
                for prevtag in self.tagset:
                    # log(γ) = α(prevtag,i-1) + score(prevtag,tag,i) + β(tag,i) - log(Z)
                    score = self.compute_score(prevtag, tag, words, i)
                    log_gamma = (
                        alpha[i - 1][prevtag]
                        + score
                        + beta[i][tag]
                        - Z
                    )
                    gamma = math.exp(log_gamma)

                    # erwartete lexikalische Features
                    for f in self.lex_features(tag, words, i):
                        freq[f] += gamma
                    # erwartete Kontextfeatures
                    for f in self.context_features(prevtag, tag, words, i):
                        freq[f] += gamma

        return freq
    def update_weights(self, words, tags):
        """Aktualisiert Gewichte mit Gradientenverfahren: w += η * (obs - exp)."""
        obs = self.observed_freq(words, tags)
        exp = self.expected_freq(words)

        for feat in set(obs.keys()) | set(exp.keys()):
            self.weights[feat] += self.learning_rate * (obs[feat] - exp[feat])


    #test
    def check_feature_names(self, words, tags):
        """Überprüft, ob alle erzeugten Merkmalsnamen korrekt formatiert sind."""
        all_features = []

        for i in range(1, len(words)):
            tag = tags[i]
            prevtag = tags[i - 1]

            all_features.extend(self.lex_features(tag, words, i))
            all_features.extend(self.context_features(prevtag, tag, words, i))

        for feat in all_features:
            if "-" in feat and "+" in feat:
                print("OK:", feat)
            else:
                print("FEHLER:", feat)

# %%
tagger = CRFTagger()

train_data = tagger.read_data("Tiger/train.txt")
#words = [w for w, _ in train_data[0]]
#tags = [t for _, t in train_data[0]]
#tagger.check_feature_names(words, tags)

# %%
train_data
# Out:
# [[('< >', '<//s>'),
#   ('``', '$('),
#   ('Ross', 'NE'),
#   ('Perot', 'NE'),
#   ('wäre', 'VAFIN'),
#   ('vielleicht', 'ADV'),
#   ('ein', 'ART'),
#   ('prächtiger', 'ADJA'),
#   ('Diktator', 'NN'),
#   ("''", '$('),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('Konzernchefs', 'NN'),
#   ('lehnen', 'VVFIN'),
#   ('den', 'ART'),
#   ('Milliardär', 'NN'),
#   ('als', 'APPR'),
#   ('US-Präsidenten', 'NN'),
#   ('ab', 'PTKVZ'),
#   ('/', '$('),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('Texaner', 'NN'),
#   ('gibt', 'VVFIN'),
#   ('nur', 'ADV'),
#   ('vage', 'ADJA'),
#   ('Auskunft', 'NN'),
#   ('über', 'APPR'),
#   ('seine', 'PPOSAT'),
#   ('Wirtschaftspolitik', 'NN'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('Der', 'ART'),
#   ('texanische', 'ADJA'),
#   ('Milliardär', 'NN'),
#   ('Ross', 'NE'),
#   ('Perot', 'NE'),
#   ('hat', 'VAFIN'),
#   ('das', 'ART'),
#   ('politische', 'ADJA'),
#   ('Establishment', 'NN'),
#   ('in', 'APPR'),
#   ('Washington', 'NE'),
#   ('aufgeschreckt', 'VVPP'),
#   ('.', '$.'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('Nach', 'APPR'),
#   ('Meinungsumfragen', 'NN'),
#   ('liegt', 'VVFIN'),
#   ('der', 'ART'),
#   ('parteilose', 'ADJA'),
#   ('Self-mademan', 'FM'),
#   ('gut', 'ADJD'),
#   ('im', 'APPRART'),
#   ('Rennen', 'NN'),
#   ('um', 'APPR'),
#   ('den', 'ART'),
#   ('Chefsessel', 'NN'),
#   ('im', 'APPRART'),
#   ('Weißen', 'ADJA'),
#   ('Haus', 'NN'),
#   ('mit', 'APPR'),
#   ('dem', 'ART'),
#   ('amtierenden', 'ADJA'),
#   ('Präsidenten', 'NN'),
#   ('George', 'NE'),
#   ('Bush', 'NE'),
#   ('und', 'KON'),
#   ('dem', 'ART'),
#   ('Demokraten', 'NN'),
#   ('Bill', 'NE'),
#   ('Clinton', 'NE'),
#   ('.', '$.'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('Daß', 'KOUS'),
#   ('Perot', 'NE'),
#   ('ein', 'ART'),
#   ('Unternehmen', 'NN'),
#   ('erfolgreich', 'ADJD'),
#   ('leiten', 'VVINF'),
#   ('kann', 'VMFIN'),
#   (',', '$,'),
#   ('davon', 'PROAV'),
#   ('sind', 'VAFIN'),
#   ('selbst', 'ADV'),
#   ('seine', 'PPOSAT'),
#   ('Kritiker', 'NN'),
#   ('überzeugt', 'VVPP'),
#   ('.', '$.'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('Ob', 'KOUS'),
#   ('diese', 'PDAT'),
#   ('Fähigkeiten', 'NN'),
#   ('aber', 'ADV'),
#   ('ausreichen', 'VVFIN'),
#   (',', '$,'),
#   ('um', 'KOUI'),
#   ('die', 'ART'),
#   ('größte', 'ADJA'),
#   ('Volkswirtschaft', 'NN'),
#   ('der', 'ART'),
#   ('Welt', 'NN'),
#   ('aus', 'APPR'),
#   ('ihrer', 'PPOSAT'),
#   ('Krise', 'NN'),
#   ('zu', 'PTKZU'),
#   ('führen', 'VVINF'),
#   (',', '$,'),
#   ('bezweifeln', 'VVFIN'),
#   ('viele', 'PIAT'),
#   ('Ökonomen', 'NN'),
#   ('.', '$.'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('Und', 'KON'),
#   ('auch', 'ADV'),
#   ('die', 'ART'),
#   ('Konzernchefs', 'NN'),
#   ('in', 'APPR'),
#   ('den', 'ART'),
#   ('USA', 'NE'),
#   ('halten', 'VVFIN'),
#   ('nicht', 'PTKNEG'),
#   ('viel', 'PIS'),
#   ('von', 'APPR'),
#   ('dem', 'ART'),
#   ('62jährigen', 'NN'),
#   ('.', '$.'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('Zwar', 'ADV'),
#   ('können', 'VMFIN'),
#   ('sich', 'PRF'),
#   ('die', 'ART'),
#   ('meisten', 'PIAT'),
#   ('Topmanager', 'NN'),
#   ('durchaus', 'ADV'),
#   ('einen', 'ART'),
#   ('Unternehmer', 'NN'),
#   ('als', 'APPR'),
#   ('Präsidenten', 'NN'),
#   ('vorstellen', 'VVINF'),
#   ('-', '$('),
#   ('nur', 'ADV'),
#   ('nicht', 'PTKNEG'),
#   ('ausgerechnet', 'ADV'),
#   ('Perot', 'NE'),
#   ('.', '$.'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('Nach', 'APPR'),
#   ('einer', 'ART'),
#   ('Umfrage', 'NN'),
#   ('des', 'ART'),
#   ('Wirtschaftsmagazins', 'NN'),
#   ('Fortune', 'NE'),
#   ('unter', 'APPR'),
#   ('den', 'ART'),
#   ('Bossen', 'NN'),
#   ('von', 'APPR'),
#   ('500', 'CARD'),
#   ('Großunternehmen', 'NN'),
#   ('wünschten', 'VVFIN'),
#   ('im', 'APPRART'),
#   ('Mai', 'NN'),
#   ('nur', 'ADV'),
#   ('elf', 'CARD'),
#   ('Prozent', 'NN'),
#   ('``', '$('),
#   ('Ross', 'NE'),
#   ('for', 'FM'),
#   ('President', 'FM'),
#   ("''", '$('),
#   (',', '$,'),
#   ('während', 'KOUS'),
#   ('78', 'CARD'),
#   ('Prozent', 'NN'),
#   ('sich', 'PRF'),
#   ('für', 'APPR'),
#   ('Bush', 'NE'),
#   ('und', 'KON'),
#   ('vier', 'CARD'),
#   ('Prozent', 'NN'),
#   ('für', 'APPR'),
#   ('Clinton', 'NE'),
#   ('aussprachen', 'VVFIN'),
#   ('.', '$.'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('Allerdings', 'ADV'),
#   ('glaubt', 'VVFIN'),
#   ('fast', 'ADV'),
#   ('die', 'ART'),
#   ('Hälfte', 'NN'),
#   ('der', 'ART'),
#   ('Chief', 'FM'),
#   ('Executives', 'FM'),
#   (',', '$,'),
#   ('daß', 'KOUS'),
#   ('Perot', 'NE'),
#   ('durchaus', 'ADV'),
#   ('Chancen', 'NN'),
#   ('habe', 'VAFIN'),
#   (',', '$,'),
#   ('die', 'ART'),
#   ('Wahl', 'NN'),
#   ('im', 'APPRART'),
#   ('November', 'NN'),
#   ('zu', 'PTKZU'),
#   ('gewinnen', 'VVINF'),
#   (',', '$,'),
#   ('wenn', 'KOUS'),
#   ('er', 'PPER'),
#   ('denn', 'ADV'),
#   ('kandidiert', 'VVFIN'),
#   ('.', '$.'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('Als', 'APPR'),
#   ('größte', 'ADJA'),
#   ('Schwäche', 'NN'),
#   ('des', 'ART'),
#   ('Texaners', 'NN'),
#   ('nennen', 'VVFIN'),
#   ('die', 'ART'),
#   ('Befragten', 'NN'),
#   ('seinen', 'PPOSAT'),
#   ('Mangel', 'NN'),
#   ('an', 'APPR'),
#   ('Erfahrung', 'NN'),
#   ('auf', 'APPR'),
#   ('dem', 'ART'),
#   ('politischen', 'ADJA'),
#   ('Parkett', 'NN'),
#   ('.', '$.'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('Viele', 'PIS'),
#   ('meinen', 'VVFIN'),
#   (',', '$,'),
#   ('daß', 'KOUS'),
#   ('Perot', 'NE'),
#   ('mit', 'APPR'),
#   ('seinem', 'PPOSAT'),
#   ('Befehlston', 'NN'),
#   ('auf', 'APPR'),
#   ('dem', 'ART'),
#   ('Capitol', 'NE'),
#   ('gegen', 'APPR'),
#   ('eine', 'ART'),
#   ('Wand', 'NN'),
#   ('laufen', 'VVINF'),
#   ('würde', 'VAFIN'),
#   ('.', '$.'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('So', 'ADV'),
#   ('erklärt', 'VVFIN'),
#   ('etwa', 'ADV'),
#   ('Edward', 'NE'),
#   ('Brandon', 'NE'),
#   ('von', 'APPR'),
#   ('dem', 'ART'),
#   ('Unternehmen', 'NN'),
#   ('National', 'NE'),
#   ('City', 'NE'),
#   ('in', 'APPR'),
#   ('Ohio', 'NE'),
#   (':', '$.'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('``', '$('),
#   ('Ich', 'PPER'),
#   ('glaube', 'VVFIN'),
#   ('kaum', 'ADV'),
#   (',', '$,'),
#   ('daß', 'KOUS'),
#   ('mit', 'APPR'),
#   ('seinem', 'PPOSAT'),
#   (',', '$,'),
#   ('naja', 'ITJ'),
#   (',', '$,'),
#   ('etwas', 'ADV'),
#   ('undiplomatischen', 'ADJA'),
#   ('Stil', 'NN'),
#   ('im', 'APPRART'),
#   ('Weißen', 'ADJA'),
#   ('Haus', 'NN'),
#   ('dem', 'ART'),
#   ('Land', 'NN'),
#   ('ein', 'ART'),
#   ('Gefallen', 'NN'),
#   ('getan', 'VVPP'),
#   ('wäre', 'VAFIN'),
#   ('.', '$.'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('Er', 'PPER'),
#   ('wäre', 'VAFIN'),
#   ('vielleicht', 'ADV'),
#   ('ein', 'ART'),
#   ('prächtiger', 'ADJA'),
#   ('Diktator', 'NN'),
#   ('-', '$('),
#   ('aber', 'KON'),
#   ('das', 'PDS'),
#   ('ist', 'VAFIN'),
#   ('nicht', 'PTKNEG'),
#   ('unser', 'PPOSAT'),
#   ('System', 'NN'),
#   ('.', '$.'),
#   ("''", '$('),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('Und', 'KON'),
#   ('ein', 'ART'),
#   ('anderer', 'ADJA'),
#   ('Manager', 'NN'),
#   ('vermutet', 'VVFIN'),
#   (',', '$,'),
#   ('daß', 'KOUS'),
#   ('sich', 'PRF'),
#   ('``', '$('),
#   ('ein', 'ART'),
#   ('Dogmatiker', 'NN'),
#   ('wie', 'KOKOM'),
#   ('Perot', 'NE'),
#   ('in', 'APPR'),
#   ('Washington', 'NE'),
#   ('schwer', 'ADJD'),
#   ('tun', 'VVINF'),
#   ('würde', 'VAFIN'),
#   (',', '$,'),
#   ('es', 'PPER'),
#   ('sei', 'VAFIN'),
#   ('denn', 'ADV'),
#   ('er', 'PPER'),
#   ('schafft', 'VVFIN'),
#   ('den', 'ART'),
#   ('Kongreß', 'NN'),
#   ('ab', 'PTKVZ'),
#   ("''", '$('),
#   ('.', '$.'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('Ein', 'ART'),
#   ('ehemaliger', 'ADJA'),
#   ('Geschäftsführer', 'NN'),
#   (',', '$,'),
#   ('der', 'PRELS'),
#   ('heute', 'ADV'),
#   ('in', 'APPR'),
#   ('fünf', 'CARD'),
#   ('Konzernen', 'NN'),
#   ('im', 'APPRART'),
#   ('Aufsichtsgremium', 'NN'),
#   ('sitzt', 'VVFIN'),
#   (',', '$,'),
#   ('``', '$('),
#   ('kennt', 'VVFIN'),
#   ('niemanden', 'PIS'),
#   (',', '$,'),
#   ('der', 'PRELS'),
#   ('nicht', 'PTKNEG'),
#   ('glaubt', 'VVFIN'),
#   (',', '$,'),
#   ('daß', 'KOUS'),
#   ('Perot', 'NE'),
#   ('als', 'APPR'),
#   ('Präsident', 'NN'),
#   ('eine', 'ART'),
#   ('absolute', 'ADJA'),
#   ('Katastrophe', 'NN'),
#   ('wäre', 'VAFIN'),
#   ("''", '$('),
#   ('.', '$.'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('Allerdings', 'ADV'),
#   ('gibt', 'VVFIN'),
#   ('es', 'PPER'),
#   ('dem', 'ART'),
#   ('Magazin', 'NN'),
#   ('zufolge', 'APPO'),
#   ('in', 'APPR'),
#   ('kleinen', 'ADJA'),
#   ('und', 'KON'),
#   ('mittleren', 'ADJA'),
#   ('Firmen', 'NN'),
#   ('viele', 'PIAT'),
#   ('Unternehmer', 'NN'),
#   (',', '$,'),
#   ('die', 'PRELS'),
#   ('meinen', 'VVFIN'),
#   (',', '$,'),
#   ('Perot', 'NE'),
#   ('sei', 'VAFIN'),
#   ('einer', 'PIS'),
#   ('von', 'APPR'),
#   ('ihnen', 'PPER'),
#   (',', '$,'),
#   ('und', 'KON'),
#   ('die', 'PRELS'),
#   ('den', 'ART'),
#   ('Texaner', 'NN'),
#   ('unterstützen', 'VVFIN'),
#   ('.', '$.'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('Zwei', 'CARD'),
#   ('Themen', 'NN'),
#   (',', '$,'),
#   ('die', 'PRELS'),
#   ('Perot', 'NE'),
#   ('immer', 'ADV'),
#   ('wieder', 'ADV'),
#   ('anspricht', 'VVFIN'),
#   (',', '$,'),
#   ('Rezession', 'NN'),
#   ('und', 'KON'),
#   ('Bürokratie', 'NN'),
#   (',', '$,'),
#   ('machen', 'VVFIN'),
#   ('ihnen', 'PPER'),
#   ('besonders', 'ADV'),
#   ('zu', 'PTKZU'),
#   ('schaffen', 'VVINF'),
#   ('.', '$.'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('Einer', 'PIS'),
#   (',', '$,'),
#   ('der', 'PRELS'),
#   ('sich', 'PRF'),
#   ('für', 'APPR'),
#   ('den', 'ART'),
#   ('Milliardär', 'NN'),
#   ('ausspricht', 'VVFIN'),
#   (',', '$,'),
#   ('ist', 'VAFIN'),
#   ('Steve', 'NE'),
#   ('Jobs', 'NE'),
#   (',', '$,'),
#   ('dem', 'PRELS'),
#   ('Perot', 'NE'),
#   ('für', 'APPR'),
#   ('den', 'ART'),
#   ('Aufbau', 'NN'),
#   ('der', 'ART'),
#   ('Computerfirma', 'NN'),
#   ('Next', 'NE'),
#   ('20', 'CARD'),
#   ('Millionen', 'NN'),
#   ('Dollar', 'NN'),
#   ('bereitstellte', 'VVFIN'),
#   ('.', '$.'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('Die', 'ART'),
#   ('Spekulationen', 'NN'),
#   ('darüber', 'PROAV'),
#   (',', '$,'),
#   ('welche', 'PWAT'),
#   ('Art', 'NN'),
#   ('Präsident', 'NN'),
#   ('``', '$('),
#   ('Henry', 'NE'),
#   ('der', 'ART'),
#   ('Hammer', 'NN'),
#   ("''", '$('),
#   (',', '$,'),
#   ('so', 'ADV'),
#   ('ein', 'ART'),
#   ('Spitzname', 'NN'),
#   ('aus', 'APPR'),
#   ('Perots', 'NE'),
#   ('Jugendzeit', 'NN'),
#   (',', '$,'),
#   ('wäre', 'VAFIN'),
#   (',', '$,'),
#   ('orientieren', 'VVFIN'),
#   ('sich', 'PRF'),
#   ('daran', 'PROAV'),
#   (',', '$,'),
#   ('wie', 'PWAV'),
#   ('Perot', 'NE'),
#   ('seine', 'PPOSAT'),
#   ('Milliarden', 'NN'),
#   ('machte', 'VVFIN'),
#   ('.', '$.'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('Die', 'ART'),
#   ('Story', 'NN'),
#   ('geht', 'VVFIN'),
#   ('so', 'ADV'),
#   (':', '$.'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('Mit', 'APPR'),
#   ('1000', 'CARD'),
#   ('von', 'APPR'),
#   ('seiner', 'PPOSAT'),
#   ('Frau', 'NN'),
#   ('geborgten', 'ADJA'),
#   ('Dollar', 'NN'),
#   ('gründet', 'VVFIN'),
#   ('der', 'ART'),
#   ('ehemalige', 'ADJA'),
#   ('IBM-Verkäufer', 'NN'),
#   ('1962', 'CARD'),
#   ('die', 'ART'),
#   ('Electronic', 'NE'),
#   ('Data', 'NE'),
#   ('Services', 'NE'),
#   ('(', '$('),
#   ('EDS', 'NE'),
#   (')', '$('),
#   ('und', 'KON'),
#   ('zeigt', 'VVFIN'),
#   ('damit', 'PROAV'),
#   ('dem', 'ART'),
#   ('Rechnergoliath', 'NN'),
#   (',', '$,'),
#   ('daß', 'KOUS'),
#   ('es', 'PPER'),
#   ('nicht', 'PTKNEG'),
#   ('nur', 'ADV'),
#   ('gilt', 'VVFIN'),
#   (',', '$,'),
#   ('Computer', 'NN'),
#   ('abzusetzen', 'VVIZU'),
#   (',', '$,'),
#   ('sondern', 'KON'),
#   ('auch', 'ADV'),
#   ('Geld', 'NN'),
#   ('damit', 'PROAV'),
#   ('zu', 'PTKZU'),
#   ('verdienen', 'VVINF'),
#   ('ist', 'VAFIN'),
#   (',', '$,'),
#   ('wenn', 'KOUS'),
#   ('man', 'PIS'),
#   ('den', 'ART'),
#   ('Benutzern', 'NN'),
#   ('beim', 'APPRART'),
#   ('Einsatz', 'NN'),
#   ('der', 'ART'),
#   ('Maschinen', 'NN'),
#   ('hilft', 'VVFIN'),
#   ('.', '$.'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('Das', 'ART'),
#   ('Informatik-Dienstleistungsunternehmen', 'NN'),
#   ('verkauft', 'VVFIN'),
#   ('er', 'PPER'),
#   ('1984', 'CARD'),
#   ('für', 'APPR'),
#   ('2,5', 'CARD'),
#   ('Milliarden', 'NN'),
#   ('an', 'APPR'),
#   ('General', 'NE'),
#   ('Motors', 'NE'),
#   ('.', '$.'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('Er', 'PPER'),
#   ('tritt', 'VVFIN'),
#   ('in', 'APPR'),
#   ('die', 'ART'),
#   ('GM-Verwaltung', 'NN'),
#   ('ein', 'PTKVZ'),
#   ('und', 'KON'),
#   ('wird', 'VAFIN'),
#   ('Großaktionär', 'NN'),
#   ('des', 'ART'),
#   ('Autokonzerns', 'NN'),
#   ('.', '$.'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('Ihm', 'PPER'),
#   ('gelingt', 'VVFIN'),
#   ('es', 'PPER'),
#   ('aber', 'ADV'),
#   ('nicht', 'PTKNEG'),
#   (',', '$,'),
#   ('den', 'ART'),
#   ('Koloß', 'NN'),
#   (',', '$,'),
#   ('der', 'PRELS'),
#   ('der', 'ART'),
#   ('Regierung', 'NN'),
#   ('in', 'APPR'),
#   ('Washington', 'NE'),
#   ('mehr', 'ADV'),
#   ('ähnelt', 'VVFIN'),
#   ('als', 'KOKOM'),
#   ('jeder', 'PIAT'),
#   ('andere', 'ADJA'),
#   ('Konzern', 'NN'),
#   (',', '$,'),
#   ('in', 'APPR'),
#   ('Schwung', 'NN'),
#   ('zu', 'PTKZU'),
#   ('bringen', 'VVINF'),
#   ('.', '$.'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('Nach', 'APPR'),
#   ('zwei', 'CARD'),
#   ('Jahren', 'NN'),
#   ('scheidet', 'VVFIN'),
#   ('er', 'PPER'),
#   ('dort', 'ADV'),
#   ('aus', 'PTKVZ'),
#   (',', '$,'),
#   ('mit', 'APPR'),
#   ('einer', 'ART'),
#   ('zusätzlichen', 'ADJA'),
#   ('GM-Zahlung', 'NN'),
#   ('von', 'APPR'),
#   ('700', 'CARD'),
#   ('Millionen', 'NN'),
#   ('Dollar', 'NN'),
#   ('in', 'APPR'),
#   ('der', 'ART'),
#   ('Tasche', 'NN'),
#   ('.', '$.'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('Heutzutage', 'ADV'),
#   ('hält', 'VVFIN'),
#   ('Perot', 'NE'),
#   ('sein', 'PPOSAT'),
#   ('Vermögen', 'NN'),
#   ('vor', 'APPR'),
#   ('allem', 'PIS'),
#   ('in', 'APPR'),
#   ('Staatspapieren', 'NN'),
#   ('und', 'KON'),
#   ('Immobilien', 'NN'),
#   ('.', '$.'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('Außerdem', 'ADV'),
#   ('gehören', 'VVFIN'),
#   ('ihm', 'PPER'),
#   ('der', 'ART'),
#   ('Computer-Dienstleister', 'NN'),
#   ('Perot', 'NE'),
#   ('Systems', 'NE'),
#   (',', '$,'),
#   ('Beteiligungen', 'NN'),
#   ('an', 'APPR'),
#   ('kleineren', 'ADJA'),
#   ('Firmen', 'NN'),
#   ('und', 'KON'),
#   ('persönliche', 'ADJA'),
#   ('Reichtümer', 'NN'),
#   ('wie', 'KOKOM'),
#   ('Jachten', 'NN'),
#   (',', '$,'),
#   ('Jets', 'NN'),
#   ('und', 'KON'),
#   ('Villen', 'NN'),
#   ('.', '$.'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('Von', 'APPR'),
#   ('modernem', 'ADJA'),
#   ('Management', 'NN'),
#   ('hat', 'VAFIN'),
#   ('Perot', 'NE'),
#   (',', '$,'),
#   ('so', 'ADV'),
#   ('Fortune', 'NE'),
#   (',', '$,'),
#   ('nie', 'ADV'),
#   ('etwas', 'PIS'),
#   ('gehalten', 'VVPP'),
#   ('.', '$.'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('Für', 'APPR'),
#   ('ihn', 'PPER'),
#   ('zählte', 'VVFIN'),
#   ('allein', 'ADV'),
#   ('``', '$('),
#   ('Führerschaft', 'NN'),
#   ("''", '$('),
#   ('.', '$.'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('Von', 'APPR'),
#   ('seinen', 'PPOSAT'),
#   ('Beschäftigten', 'NN'),
#   ('verlange', 'VVFIN'),
#   ('er', 'PPER'),
#   ('vor', 'APPR'),
#   ('allem', 'PIS'),
#   ('Arbeitsmoral', 'NN'),
#   ('und', 'KON'),
#   ('ordentliches', 'ADJA'),
#   ('Auftreten', 'NN'),
#   ('.', '$.'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('Perot', 'NE'),
#   ('sei', 'VAFIN'),
#   ('ein', 'ART'),
#   ('autoritärer', 'ADJA'),
#   ('Macher', 'NN'),
#   (',', '$,'),
#   ('und', 'KON'),
#   ('das', 'PDS'),
#   ('sei', 'VAFIN'),
#   ('auch', 'ADV'),
#   ('seine', 'PPOSAT'),
#   ('Schwäche', 'NN'),
#   (',', '$,'),
#   ('beschreibt', 'VVFIN'),
#   ('ihn', 'PPER'),
#   ('ein', 'ART'),
#   ('Manager', 'NN'),
#   ('.', '$.'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('Die', 'ART'),
#   ('Kritik', 'NN'),
#   ('der', 'ART'),
#   ('Ökonomenzunft', 'NN'),
#   ('an', 'APPR'),
#   ('Perot', 'NE'),
#   ('entzündet', 'VVFIN'),
#   ('sich', 'PRF'),
#   ('vor', 'APPR'),
#   ('allem', 'PIS'),
#   ('an', 'APPR'),
#   ('dessen', 'PDS'),
#   ('vagen', 'ADJA'),
#   ('Äußerungen', 'NN'),
#   ('zur', 'APPRART'),
#   ('Wirtschaftspolitik', 'NN'),
#   ('.', '$.'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('``', '$('),
#   ('Es', 'PPER'),
#   ('ist', 'VAFIN'),
#   ('wirklich', 'ADJD'),
#   ('schwer', 'ADJD'),
#   ('zu', 'PTKZU'),
#   ('sagen', 'VVINF'),
#   (',', '$,'),
#   ('welche', 'PWAT'),
#   ('Positionen', 'NN'),
#   ('er', 'PPER'),
#   ('einnimmt', 'VVFIN'),
#   (',', '$,'),
#   ('da', 'KOUS'),
#   ('er', 'PPER'),
#   ('sich', 'PRF'),
#   ('noch', 'ADV'),
#   ('nicht', 'PTKNEG'),
#   ('konkret', 'ADJD'),
#   ('geäußert', 'VVPP'),
#   ('hat', 'VAFIN'),
#   ("''", '$('),
#   (',', '$,'),
#   ('beklagen', 'VVFIN'),
#   ('Volkswirte', 'NN'),
#   ('.', '$.'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('Bisher', 'ADV'),
#   ('bestehe', 'VVFIN'),
#   ('sein', 'PPOSAT'),
#   ('``', '$('),
#   ('Programm', 'NN'),
#   ("''", '$('),
#   ('nur', 'ADV'),
#   ('aus', 'APPR'),
#   ('Allgemeinplätzen', 'NN'),
#   ('.', '$.'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('So', 'ADV'),
#   ('will', 'VMFIN'),
#   ('der', 'ART'),
#   ('politische', 'ADJA'),
#   ('Außenseiter', 'NN'),
#   ('beispielsweise', 'ADV'),
#   ('das', 'ART'),
#   ('Steuersystem', 'NN'),
#   ('vereinfachen', 'VVINF'),
#   (',', '$,'),
#   ('das', 'ART'),
#   ('Bildungssystem', 'NN'),
#   ('verbessern', 'VVINF'),
#   (',', '$,'),
#   ('das', 'ART'),
#   ('gigantische', 'ADJA'),
#   ('Haushaltsdefizit', 'NN'),
#   ('abbauen', 'VVINF'),
#   (',', '$,'),
#   ('Einfuhren', 'NN'),
#   ('aus', 'APPR'),
#   ('Japan', 'NE'),
#   ('drosseln', 'VVINF'),
#   ('und', 'KON'),
#   ('die', 'ART'),
#   ('geplante', 'ADJA'),
#   ('Freihandelszone', 'NN'),
#   ('der', 'ART'),
#   ('USA', 'NE'),
#   ('mit', 'APPR'),
#   ('Mexiko', 'NE'),
#   ('verhindern', 'VVINF'),
#   ('.', '$.'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('Wie', 'PWAV'),
#   ('er', 'PPER'),
#   ('diese', 'PDAT'),
#   ('Aufgaben', 'NN'),
#   ('lösen', 'VVINF'),
#   ('will', 'VMFIN'),
#   (',', '$,'),
#   ('verrät', 'VVFIN'),
#   ('er', 'PPER'),
#   ('aber', 'ADV'),
#   ('nicht', 'PTKNEG'),
#   ('.', '$.'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('Statt', 'KOUI'),
#   ('Details', 'NN'),
#   ('zu', 'PTKZU'),
#   ('nennen', 'VVINF'),
#   (',', '$,'),
#   ('wiederholt', 'VVFIN'),
#   ('er', 'PPER'),
#   ('unverdrossen', 'ADJD'),
#   ('die', 'ART'),
#   ('``', '$('),
#   ('Erfolgsformel', 'NN'),
#   ("''", '$('),
#   (':', '$.'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('Die', 'ART'),
#   ('Amerikaner', 'NN'),
#   ('müssen', 'VMFIN'),
#   ('hart', 'ADJD'),
#   ('arbeiten', 'VVINF'),
#   (',', '$,'),
#   ('um', 'KOUI'),
#   ('das', 'ART'),
#   ('Land', 'NN'),
#   ('wieder', 'ADV'),
#   ('auf', 'APPR'),
#   ('den', 'ART'),
#   ('richtigen', 'ADJA'),
#   ('Kurs', 'NN'),
#   ('zu', 'PTKZU'),
#   ('bringen', 'VVINF'),
#   ('.', '$.'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('``', '$('),
#   ('Die', 'ART'),
#   ('Probleme', 'NN'),
#   ('unseres', 'PPOSAT'),
#   ('Landes', 'NN'),
#   ('sind', 'VAFIN'),
#   ('doch', 'ADV'),
#   ('weit', 'ADJD'),
#   ('größer', 'ADJD'),
#   ('als', 'KOKOM'),
#   ('die', 'PDS'),
#   ('eines', 'ART'),
#   ('Unternehmens', 'NN'),
#   ("''", '$('),
#   (',', '$,'),
#   ('meint', 'VVFIN'),
#   ('Rudy', 'NE'),
#   ('Oswald', 'NE'),
#   (',', '$,'),
#   ('Chefvolkswirt', 'NN'),
#   ('beim', 'APPRART'),
#   ('Gewerkschaftsbund', 'NN'),
#   ('AFL-CIO', 'NE'),
#   ('.', '$.'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('Schließlich', 'ADV'),
#   ('sei', 'VAFIN'),
#   ('die', 'ART'),
#   ('Regierung', 'NN'),
#   ('auch', 'ADV'),
#   ('für', 'APPR'),
#   ('die', 'ART'),
#   ('nationale', 'ADJA'),
#   ('Sicherheit', 'NN'),
#   ('und', 'KON'),
#   ('allgemeine', 'ADJA'),
#   ('Wohlfahrt', 'NN'),
#   ('verantwortlich', 'ADJD'),
#   ('.', '$.'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('``', '$('),
#   ('Hier', 'ADV'),
#   ('geht', 'VVFIN'),
#   ('es', 'PPER'),
#   ('um', 'APPR'),
#   ('mehr', 'PIS'),
#   (',', '$,'),
#   ('als', 'KOKOM'),
#   ('nur', 'ADV'),
#   ('Profit', 'NN'),
#   ('zu', 'PTKZU'),
#   ('machen', 'VVINF'),
#   ("''", '$('),
#   (',', '$,'),
#   ('fügt', 'VVFIN'),
#   ('er', 'PPER'),
#   ('hinzu', 'PTKVZ'),
#   ('.', '$.'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('``', '$('),
#   ('Geschäftemachen', 'NN'),
#   ('ist', 'VAFIN'),
#   ('seine', 'PPOSAT'),
#   ('Welt', 'NN'),
#   ('und', 'KON'),
#   ('nicht', 'PTKNEG'),
#   ('die', 'ART'),
#   ('Politik', 'NN'),
#   ('.', '$.'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('Er', 'PPER'),
#   ('ist', 'VAFIN'),
#   ('ein', 'ART'),
#   ('eigenwilliger', 'ADJA'),
#   ('Einzelgänger', 'NN'),
#   (',', '$,'),
#   ('der', 'PRELS'),
#   ('sich', 'PRF'),
#   ('zudem', 'ADV'),
#   ('nicht', 'PTKNEG'),
#   ('an', 'APPR'),
#   ('Spielregeln', 'NN'),
#   ('hält', 'VVFIN'),
#   ("''", '$('),
#   (',', '$,'),
#   ('zeigt', 'VVFIN'),
#   ('sich', 'PRF'),
#   ('ein', 'ART'),
#   ('anderer', 'ADJA'),
#   ('Fachmann', 'NN'),
#   ('skeptisch', 'ADJD'),
#   ('.', '$.'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('Früher', 'ADJD'),
#   ('oder', 'KON'),
#   ('später', 'ADJD'),
#   (',', '$,'),
#   ('da', 'ADV'),
#   ('sind', 'VAFIN'),
#   ('sich', 'PRF'),
#   ('alle', 'PIS'),
#   ('einig', 'ADJD'),
#   (',', '$,'),
#   ('muß', 'VMFIN'),
#   ('Perot', 'NE'),
#   ('Farbe', 'NN'),
#   ('bekennen', 'VVINF'),
#   ('und', 'KON'),
#   ('Konzepte', 'NN'),
#   ('vorlegen', 'VVINF'),
#   ('.', '$.'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('``', '$('),
#   ('Die', 'ART'),
#   ('Frage', 'NN'),
#   ('ist', 'VAFIN'),
#   ('nur', 'ADV'),
#   ("''", '$('),
#   (',', '$,'),
#   ('meint', 'VVFIN'),
#   ('ein', 'ART'),
#   ('Finanzexperte', 'NN'),
#   (',', '$,'),
#   ('``', '$('),
#   ('ob', 'KOUS'),
#   ('er', 'PPER'),
#   ('ins', 'APPRART'),
#   ('Weiße', 'ADJA'),
#   ('Haus', 'NN'),
#   ('einziehen', 'VVINF'),
#   ('kann', 'VMFIN'),
#   (',', '$,'),
#   ('ohne', 'KOUI'),
#   ('uns', 'PPER'),
#   ('vorher', 'ADV'),
#   ('zu', 'PTKZU'),
#   ('sagen', 'VVINF'),
#   (',', '$,'),
#   ('was', 'PWS'),
#   ('er', 'PPER'),
#   ('eigentlich', 'ADV'),
#   ('machen', 'VVINF'),
#   ('will', 'VMFIN'),
#   ('.', '$.'),
#   ("''", '$('),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('sch', 'XY'),
#   ('/', '$('),
#   ('rtr', 'NE'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('IBM', 'NE'),
#   ('und', 'KON'),
#   ('Siemens', 'NE'),
#   ('gelten', 'VVFIN'),
#   ('nicht', 'PTKNEG'),
#   ('mehr', 'ADV'),
#   ('als', 'APPR'),
#   ('Schimpfworte', 'NN'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('Ausländische', 'ADJA'),
#   ('Investoren', 'NN'),
#   ('in', 'APPR'),
#   ('Indien', 'NE'),
#   ('wieder', 'ADV'),
#   ('willkommen', 'ADJD'),
#   ('/', '$('),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('Premierminister', 'NN'),
#   ('Rao', 'NE'),
#   ('wagt', 'VVFIN'),
#   ('revolutionäre', 'ADJA'),
#   ('Wirtschaftsreform', 'NN'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('Als', 'KOUS'),
#   ('vor', 'APPR'),
#   ('gut', 'ADJD'),
#   ('einem', 'ART'),
#   ('Jahr', 'NN'),
#   ('der', 'ART'),
#   ('71', 'CARD'),
#   ('Jahre', 'NN'),
#   ('alte', 'ADJA'),
#   ('Narasimha', 'NE'),
#   ('Rao', 'NE'),
#   ('den', 'ART'),
#   ('Premierminister-Sessel', 'NN'),
#   ('in', 'APPR'),
#   ('Indien', 'NE'),
#   ('erklomm', 'VVFIN'),
#   (',', '$,'),
#   ('da', 'ADV'),
#   ('glaubte', 'VVFIN'),
#   ('kaum', 'ADV'),
#   ('jemand', 'PIS'),
#   (',', '$,'),
#   ('daß', 'KOUS'),
#   ('er', 'PPER'),
#   ('mehr', 'PIS'),
#   ('würde', 'VAFIN'),
#   ('als', 'KOKOM'),
#   ('das', 'PDS'),
#   (',', '$,'),
#   ('wozu', 'PWAV'),
#   ('ihn', 'PPER'),
#   ('die', 'ART'),
#   ('Führer', 'NN'),
#   ('der', 'ART'),
#   ('Congress-Partei', 'NN'),
#   ('abstempeln', 'VVINF'),
#   ('wollten', 'VMFIN'),
#   (':', '$.'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('ein', 'ART'),
#   ('farbloser', 'ADJA'),
#   ('Kompromißkandidat', 'NN'),
#   ('und', 'KON'),
#   ('Regierungschef', 'NN'),
#   ('für', 'APPR'),
#   ('den', 'ART'),
#   ('Übergang', 'NN'),
#   ('bis', 'APPR'),
#   ('zum', 'APPRART'),
#   ('Abschluß', 'NN'),
#   ('der', 'ART'),
#   ('Machtkämpfe', 'NN'),
#   ('.', '$.'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('Heute', 'ADV'),
#   ('weiß', 'VVFIN'),
#   ('man', 'PIS'),
#   ('es', 'PPER'),
#   ('besser', 'ADJD'),
#   ('.', '$.'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('Rao', 'NE'),
#   ('und', 'KON'),
#   ('der', 'ART'),
#   ('zum', 'APPRART'),
#   ('Finanzminister', 'NN'),
#   ('bestellte', 'ADJA'),
#   ('Technokrat', 'NN'),
#   ('Manmohan', 'NE'),
#   ('Singh', 'NE'),
#   ('verordneten', 'VVFIN'),
#   ('dem', 'ART'),
#   ('Subkontinent', 'NN'),
#   ('den', 'ART'),
#   ('revolutionärsten', 'ADJA'),
#   ('Wandel', 'NN'),
#   ('in', 'APPR'),
#   ('seiner', 'PPOSAT'),
#   ('Geschichte', 'NN'),
#   ('.', '$.'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('Sie', 'PPER'),
#   ('haben', 'VAFIN'),
#   ('den', 'ART'),
#   ('längst', 'ADV'),
#   ('überfälligen', 'ADJA'),
#   ('Bruch', 'NN'),
#   ('mit', 'APPR'),
#   ('der', 'ART'),
#   ('Vergangenheit', 'NN'),
#   ('vollzogen', 'VVPP'),
#   (',', '$,'),
#   ('vor', 'APPR'),
#   ('dem', 'PRELS'),
#   ('noch', 'ADV'),
#   ('jeder', 'PIS'),
#   ('ihrer', 'PPOSAT'),
#   ('Vorgänger', 'NN'),
#   ('zurückgeschreckt', 'VVPP'),
#   ('war', 'VAFIN'),
#   (':', '$.'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('die', 'ART'),
#   ('Abkehr', 'NN'),
#   ('von', 'APPR'),
#   ('Nehrus', 'NE'),
#   ('Staatssozialismus', 'NN'),
#   ('nach', 'APPR'),
#   ('sowjetischem', 'ADJA'),
#   ('Vorbild', 'NN'),
#   ('.', '$.'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('Wenn', 'KOUS'),
#   ('die', 'ART'),
#   ('Wirtschaftsreform', 'NN'),
#   ('gelingt', 'VVFIN'),
#   (',', '$,'),
#   ('so', 'ADV'),
#   ('sagt', 'VVFIN'),
#   ('der', 'ART'),
#   ('kritische', 'ADJA'),
#   ('Economist', 'NE'),
#   ('voraus', 'PTKVZ'),
#   (',', '$,'),
#   ('dann', 'ADV'),
#   ('kann', 'VMFIN'),
#   ('in', 'APPR'),
#   ('Indien', 'NE'),
#   ('schon', 'ADV'),
#   ('in', 'APPR'),
#   ('einer', 'ART'),
#   ('Generation', 'NN'),
#   ('der', 'ART'),
#   ('Mittelstand', 'NN'),
#   ('eine', 'ART'),
#   ('Milliarde', 'NN'),
#   ('Menschen', 'NN'),
#   ('zählen', 'VVINF'),
#   ('.', '$.'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('``', '$('),
#   ('Den', 'ART'),
#   ('Herren', 'NN'),
#   ('Rao', 'NE'),
#   ('und', 'KON'),
#   ('Singh', 'NE'),
#   ('gebührt', 'VVFIN'),
#   ('ein', 'ART'),
#   ('Platz', 'NN'),
#   ('in', 'APPR'),
#   ('der', 'ART'),
#   ('Geschichte', 'NN'),
#   ("''", '$('),
#   (',', '$,'),
#   ('resumiert', 'VVFIN'),
#   ('das', 'ART'),
#   ('britische', 'ADJA'),
#   ('Blatt', 'NN'),
#   ('.', '$.'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('Ob', 'KOUS'),
#   ('das', 'PDS'),
#   ('freilich', 'ADV'),
#   ('so', 'ADV'),
#   ('klappt', 'VVFIN'),
#   (',', '$,'),
#   ('ist', 'VAFIN'),
#   ('die', 'ART'),
#   ('Frage', 'NN'),
#   ('.', '$.'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('Gewiß', 'ADV'),
#   ('-', '$('),
#   ('die', 'ART'),
#   ('wirtschaftliche', 'ADJA'),
#   ('Liberalisierung', 'NN'),
#   ('und', 'KON'),
#   ('Öffnung', 'NN'),
#   ('des', 'ART'),
#   ('Landes', 'NN'),
#   ('schreiten', 'VVFIN'),
#   ('voran', 'PTKVZ'),
#   ('.', '$.'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('Vorbei', 'ADV'),
#   ('sind', 'VAFIN'),
#   ('die', 'ART'),
#   ('Zeiten', 'NN'),
#   (',', '$,'),
#   ('in', 'APPR'),
#   ('denen', 'PRELS'),
#   ('eine', 'ART'),
#   ('übermächtige', 'ADJA'),
#   ('Bürokratie', 'NN'),
#   ('ausländische', 'ADJA'),
#   ('Investoren', 'NN'),
#   ('vergraulte', 'VVFIN'),
#   ('.', '$.'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('Nun', 'ADV'),
#   ('werden', 'VAFIN'),
#   ('sie', 'PPER'),
#   ('umworben', 'VVPP'),
#   ('.', '$.'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('Und', 'KON'),
#   ('Coca', 'NE'),
#   ('Cola', 'NE'),
#   (',', '$,'),
#   ('IBM', 'NE'),
#   (',', '$,'),
#   ('Siemens', 'NE'),
#   ('oder', 'KON'),
#   ('BMW', 'NE'),
#   ('sind', 'VAFIN'),
#   ('keine', 'PIAT'),
#   ('Schimpf-Bezeichnungen', 'NN'),
#   ('mehr', 'ADV'),
#   ('.', '$.'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('Wo', 'PWAV'),
#   ('früher', 'ADJD'),
#   ('nur', 'ADV'),
#   ('für', 'APPR'),
#   ('einen', 'ART'),
#   ('abgeschotteten', 'ADJA'),
#   ('Markt', 'NN'),
#   ('qualitatitiv', 'ADJD'),
#   ('minderwertige', 'ADJA'),
#   ('Ware', 'NN'),
#   ('hergestellt', 'VVPP'),
#   ('wurde', 'VAFIN'),
#   (',', '$,'),
#   ('heißt', 'VVFIN'),
#   ('die', 'ART'),
#   ('Losung', 'NN'),
#   ('nun', 'ADV'),
#   ('Wettbewerb', 'NN'),
#   ('und', 'KON'),
#   ('Export', 'NN'),
#   ('.', '$.'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('Während', 'KOUS'),
#   ('die', 'ART'),
#   ('neuen', 'ADJA'),
#   ('Tiger', 'NN'),
#   ('Asiens', 'NE'),
#   ('wirtschaftlich', 'ADJD'),
#   ('vorbeizogen', 'VVFIN'),
#   (',', '$,'),
#   ('kam', 'VVFIN'),
#   ('der', 'ART'),
#   ('Gigant', 'NN'),
#   (',', '$,'),
#   ('dessen', 'PRELAT'),
#   ('Geschäftsleute', 'NN'),
#   ('nur', 'ADV'),
#   ('im', 'APPRART'),
#   ('Ausland', 'NN'),
#   ('demonstrieren', 'VVINF'),
#   ('konnten', 'VMFIN'),
#   (',', '$,'),
#   ('was', 'PWS'),
#   ('in', 'APPR'),
#   ('ihnen', 'PPER'),
#   ('steckt', 'VVFIN'),
#   (',', '$,'),
#   ('nicht', 'PTKNEG'),
#   ('voran', 'PTKVZ'),
#   ('.', '$.'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('Als', 'KOUS'),
#   ('Rao', 'NE'),
#   ('die', 'ART'),
#   ('Regierung', 'NN'),
#   ('übernahm', 'VVFIN'),
#   (',', '$,'),
#   ('gab', 'VVFIN'),
#   ('es', 'PPER'),
#   ('praktisch', 'ADJD'),
#   ('kein', 'PIAT'),
#   ('Wirtschaftswachstum', 'NN'),
#   ('mehr', 'ADV'),
#   ('.', '$.'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('Das', 'ART'),
#   ('Land', 'NN'),
#   ('war', 'VAFIN'),
#   ('so', 'ADV'),
#   ('verschuldet', 'ADJD'),
#   (',', '$,'),
#   ('daß', 'KOUS'),
#   ('niemand', 'PIS'),
#   ('neue', 'ADJA'),
#   ('Kredite', 'NN'),
#   ('einräumen', 'VVINF'),
#   ('wollte', 'VMFIN'),
#   (',', '$,'),
#   ('die', 'ART'),
#   ('Devisenreserven', 'NN'),
#   ('entsprachen', 'VVFIN'),
#   ('nur', 'ADV'),
#   ('noch', 'ADV'),
#   ('den', 'ART'),
#   ('Importen', 'NN'),
#   ('eines', 'ART'),
#   ('Monats', 'NN'),
#   (',', '$,'),
#   ('das', 'ART'),
#   ('Haushaltsdefizit', 'NN'),
#   ('lautete', 'VVFIN'),
#   ('auf', 'APPR'),
#   ('neun', 'CARD'),
#   ('Prozent', 'NN'),
#   ('des', 'ART'),
#   ('Bruttosozialprodukts', 'NN'),
#   ('.', '$.'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('Nach', 'APPR'),
#   ('dem', 'ART'),
#   ('Mord', 'NN'),
#   ('an', 'APPR'),
#   ('Rajiv', 'NE'),
#   ('Gandhi', 'NE'),
#   (',', '$,'),
#   ('den', 'ART'),
#   ('blutigen', 'ADJA'),
#   ('Kasten-', 'TRUNC'),
#   ('und', 'KON'),
#   ('Religionskriegen', 'NN'),
#   ('und', 'KON'),
#   ('den', 'ART'),
#   ('bürgerkriegsähnlichen', 'ADJA'),
#   ('Zuständen', 'NN'),
#   ('in', 'APPR'),
#   ('Kaschmir', 'NE'),
#   (',', '$,'),
#   ('Punjab', 'NE'),
#   ('und', 'KON'),
#   ('Assam', 'NE'),
#   ('steckte', 'VVFIN'),
#   ('das', 'ART'),
#   ('Land', 'NN'),
#   ('in', 'APPR'),
#   ('der', 'ART'),
#   ('tiefsten', 'ADJA'),
#   ('Krise', 'NN'),
#   ('seit', 'APPR'),
#   ('der', 'ART'),
#   ('Unabhängigkeit', 'NN'),
#   ('.', '$.'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('Angst', 'NN'),
#   ('beherrschte', 'VVFIN'),
#   ('die', 'ART'),
#   ('Szene', 'NN'),
#   ('.', '$.'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('Doch', 'KON'),
#   ('das', 'ART'),
#   ('Team', 'NN'),
#   ('Rao', 'NE'),
#   ('/', '$('),
#   ('Singh', 'NE'),
#   ('hat', 'VAFIN'),
#   ('es', 'PPER'),
#   ('geschafft', 'VVPP'),
#   (',', '$,'),
#   ('Indien', 'NE'),
#   ('Zuversicht', 'NN'),
#   ('einzuflößen', 'VVIZU'),
#   (',', '$,'),
#   ('obwohl', 'KOUS'),
#   ('der', 'ART'),
#   ('Aufschwung', 'NN'),
#   ('in', 'APPR'),
#   ('der', 'ART'),
#   ('Statistik', 'NN'),
#   ('noch', 'ADV'),
#   ('nicht', 'PTKNEG'),
#   ('zum', 'APPRART'),
#   ('Ausdruck', 'NN'),
#   ('kommt', 'VVFIN'),
#   ('.', '$.'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('Im', 'APPRART'),
#   ('Gegenteil', 'NN'),
#   ('.', '$.'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('Die', 'ART'),
#   ('Inflation', 'NN'),
#   ('liegt', 'VVFIN'),
#   ('bei', 'APPR'),
#   ('13', 'CARD'),
#   ('Prozent', 'NN'),
#   (',', '$,'),
#   ('die', 'ART'),
#   ('Industrieproduktion', 'NN'),
#   ('ist', 'VAFIN'),
#   ('1991', 'CARD'),
#   ('gesunken', 'VVPP'),
#   (',', '$,'),
#   ('die', 'ART'),
#   ('Zahl', 'NN'),
#   ('der', 'ART'),
#   ('Arbeitslosen', 'NN'),
#   ('gestiegen', 'VVPP'),
#   ('.', '$.'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('Lediglich', 'ADV'),
#   ('das', 'ART'),
#   ('Devisenpolster', 'NN'),
#   ('schwoll', 'VVFIN'),
#   ('an', 'PTKVZ'),
#   ('.', '$.'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('Nach', 'APPR'),
#   ('einer', 'ART'),
#   ('Zwei-Milliarden-Dollar-Spritze', 'NN'),
#   ('des', 'ART'),
#   ('Internationalen', 'ADJA'),
#   ('Währungsfonds', 'NN'),
#   ('ist', 'VAFIN'),
#   ('es', 'PPER'),
#   ('jetzt', 'ADV'),
#   ('6,5', 'CARD'),
#   ('Milliarden', 'NN'),
#   ('Dollar', 'NN'),
#   ('dick', 'ADJD'),
#   ('.', '$.'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('Doch', 'KON'),
#   ('der', 'ART'),
#   ('Fortschritt', 'NN'),
#   ('geht', 'VVFIN'),
#   ('dem', 'ART'),
#   ('Regierungschef', 'NN'),
#   ('nicht', 'PTKNEG'),
#   ('schnell', 'ADJD'),
#   ('genug', 'ADV'),
#   ('.', '$.'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('Er', 'PPER'),
#   ('weiß', 'VVFIN'),
#   ('um', 'APPR'),
#   ('die', 'ART'),
#   ('Ungeduld', 'NN'),
#   ('seiner', 'PPOSAT'),
#   ('Landsleute', 'NN'),
#   (',', '$,'),
#   ('für', 'APPR'),
#   ('die', 'PRELS'),
#   ('notwendige', 'ADJA'),
#   ('Strukturanpassungen', 'NN'),
#   ('erst', 'ADV'),
#   ('einmal', 'ADV'),
#   ('``', '$('),
#   ('Gürtel', 'NN'),
#   ('enger', 'ADJD'),
#   ('schnallen', 'VVINF'),
#   ("''", '$('),
#   ('heißen', 'VVFIN'),
#   ('.', '$.'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('Das', 'PDS'),
#   ('fällt', 'VVFIN'),
#   ('schon', 'ADV'),
#   ('deshalb', 'PROAV'),
#   ('schwer', 'PTKVZ'),
#   (',', '$,'),
#   ('weil', 'KOUS'),
#   ('fast', 'ADV'),
#   ('die', 'ART'),
#   ('Hälfte', 'NN'),
#   ('der', 'ART'),
#   ('Bevölkerung', 'NN'),
#   ('unter', 'APPR'),
#   ('dem', 'ART'),
#   ('Existenzminimum', 'NN'),
#   ('lebt', 'VVFIN'),
#   ('.', '$.'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('Deshalb', 'PROAV'),
#   ('drängt', 'VVFIN'),
#   ('Rao', 'NE'),
#   ('seinen', 'PPOSAT'),
#   ('Finanzminister', 'NN'),
#   (',', '$,'),
#   ('noch', 'ADV'),
#   ('stärker', 'ADJD'),
#   ('die', 'ART'),
#   ('Werbetrommel', 'NN'),
#   ('bei', 'APPR'),
#   ('ausländischen', 'ADJA'),
#   ('Investoren', 'NN'),
#   ('zu', 'PTKZU'),
#   ('rühren', 'VVINF'),
#   (',', '$,'),
#   ('noch', 'ADV'),
#   ('mehr', 'ADV'),
#   ('in', 'APPR'),
#   ('Optimismus', 'NN'),
#   ('zu', 'PTKZU'),
#   ('machen', 'VVINF'),
#   ('.', '$.'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('Die', 'ART'),
#   ('vielen', 'PIAT'),
#   ('wohlwollenden', 'ADJA'),
#   ('Absichtserklärungen', 'NN'),
#   ('sollen', 'VMFIN'),
#   ('sich', 'PRF'),
#   ('in', 'APPR'),
#   ('Taten', 'NN'),
#   ('niederschlagen', 'VVINF'),
#   ('.', '$.'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('Auch', 'ADV'),
#   ('wenn', 'KOUS'),
#   ('Manmohan', 'NE'),
#   ('Singh', 'NE'),
#   ('immer', 'ADV'),
#   ('wieder', 'ADV'),
#   ('versichert', 'VVFIN'),
#   (',', '$,'),
#   ('er', 'PPER'),
#   ('rechne', 'VVFIN'),
#   ('nach', 'APPR'),
#   ('der', 'ART'),
#   ('Öffnung', 'NN'),
#   ('der', 'ART'),
#   ('indischen', 'ADJA'),
#   ('Wirtschaft', 'NN'),
#   ('mit', 'APPR'),
#   ('ausländischen', 'ADJA'),
#   ('Investitionen', 'NN'),
#   ('von', 'APPR'),
#   ('bis', 'ADV'),
#   ('zu', 'ADV'),
#   ('sechs', 'CARD'),
#   ('Milliarden', 'NN'),
#   ('Dollar', 'NN'),
#   ('im', 'APPRART'),
#   ('Laufe', 'NN'),
#   ('der', 'ART'),
#   ('nächsten', 'ADJA'),
#   ('drei', 'CARD'),
#   ('Jahre', 'NN'),
#   (',', '$,'),
#   ('so', 'ADV'),
#   ('sind', 'VAFIN'),
#   ('bis', 'APPR'),
#   ('Ende', 'NN'),
#   ('März', 'NN'),
#   ('nicht', 'PTKNEG'),
#   ('mehr', 'PIS'),
#   ('als', 'KOKOM'),
#   ('480', 'CARD'),
#   ('Millionen', 'NN'),
#   ('ins', 'APPRART'),
#   ('Land', 'NN'),
#   ('geflossen', 'VVPP'),
#   ('.', '$.'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('Immer', 'ADV'),
#   ('wieder', 'ADV'),
#   ('heißt', 'VVFIN'),
#   ('es', 'PPER'),
#   (',', '$,'),
#   ('nun', 'ADV'),
#   ('würden', 'VAFIN'),
#   ('die', 'ART'),
#   ('Japaner', 'NN'),
#   ('und', 'KON'),
#   ('die', 'ART'),
#   ('Deutschen', 'NN'),
#   ('massiv', 'ADJD'),
#   ('einsteigen', 'VVINF'),
#   (',', '$,'),
#   ('aber', 'KON'),
#   ('der', 'ART'),
#   ('große', 'ADJA'),
#   ('Durchbruch', 'NN'),
#   ('läßt', 'VVFIN'),
#   ('auf', 'APPR'),
#   ('sich', 'PRF'),
#   ('warten', 'VVINF'),
#   ('.', '$.'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('Die', 'ART'),
#   ('zahlreichen', 'ADJA'),
#   ('Geschäftsleute', 'NN'),
#   (',', '$,'),
#   ('die', 'PRELS'),
#   ('sich', 'PRF'),
#   ('in', 'APPR'),
#   ('Delhi', 'NE'),
#   ('die', 'ART'),
#   ('Klinke', 'NN'),
#   ('in', 'APPR'),
#   ('die', 'ART'),
#   ('Hand', 'NN'),
#   ('geben', 'VVFIN'),
#   (',', '$,'),
#   ('sehen', 'VVFIN'),
#   ('durchaus', 'ADV'),
#   ('das', 'ART'),
#   ('Potential', 'NN'),
#   ('Indiens', 'NE'),
#   ('als', 'APPR'),
#   ('Markt', 'NN'),
#   ('wie', 'KON'),
#   ('auch', 'ADV'),
#   ('als', 'APPR'),
#   ('Produktionsstandort', 'NN'),
#   ('.', '$.'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('Aber', 'KON'),
#   ('sie', 'PPER'),
#   ('zögern', 'VVFIN'),
#   ('.', '$.'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('Dafür', 'PROAV'),
#   ('gibt', 'VVFIN'),
#   ('es', 'PPER'),
#   ('Gründe', 'NN'),
#   ('.', '$.'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('Denn', 'KON'),
#   ('nach', 'ADV'),
#   ('wie', 'KON'),
#   ('vor', 'ADV'),
#   ('hapert', 'VVFIN'),
#   ('es', 'PPER'),
#   ('gewaltig', 'ADJD'),
#   ('mit', 'APPR'),
#   ('der', 'ART'),
#   ('Infrastruktur', 'NN'),
#   (',', '$,'),
#   ('die', 'PRELS'),
#   ('eine', 'ART'),
#   ('Voraussetzung', 'NN'),
#   ('für', 'APPR'),
#   ('lukrative', 'ADJA'),
#   ('Geschäfte', 'NN'),
#   ('ist', 'VAFIN'),
#   ('.', '$.'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('Mängel', 'NN'),
#   ('in', 'APPR'),
#   ('der', 'ART'),
#   ('Energieversorgung', 'NN'),
#   ('(', '$('),
#   ('der', 'ART'),
#   ('Strombedarf', 'NN'),
#   ('ist', 'VAFIN'),
#   ('nur', 'ADV'),
#   ('zu', 'APPR'),
#   ('80', 'CARD'),
#   ('Prozent', 'NN'),
#   ('gesichert', 'VVPP'),
#   (')', '$('),
#   (',', '$,'),
#   ('eine', 'ART'),
#   ('vorsintflutliche', 'ADJA'),
#   ('Telekommunikation', 'NN'),
#   ('mit', 'APPR'),
#   ('ständig', 'ADJD'),
#   ('ausfallenden', 'ADJA'),
#   ('Telefonen', 'NN'),
#   ('und', 'KON'),
#   ('Telefax-Geräten', 'NN'),
#   (',', '$,'),
#   ('schlechte', 'ADJA'),
#   ('Straßen', 'NN'),
#   (',', '$,'),
#   ('verstopfte', 'ADJA'),
#   ('Häfen', 'NN'),
#   (',', '$,'),
#   ('langsame', 'ADJA'),
#   ('Eisenbahnen', 'NN'),
#   ('und', 'KON'),
#   ('eine', 'ART'),
#   ('miese', 'ADJA'),
#   ('Arbeitsmoral', 'NN'),
#   ('bilden', 'VVFIN'),
#   ('eine', 'ART'),
#   ('Mixtur', 'NN'),
#   (',', '$,'),
#   ('die', 'PRELS'),
#   ('selbst', 'ADV'),
#   ('optimistische', 'ADJA'),
#   ('Investoren', 'NN'),
#   ('abschreckt', 'VVFIN'),
#   ('.', '$.'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('Auch', 'ADV'),
#   ('an', 'APPR'),
#   ('die', 'ART'),
#   ('heißesten', 'ADJA'),
#   ('Eisen', 'NN'),
#   ('hat', 'VAFIN'),
#   ('sich', 'PRF'),
#   ('die', 'ART'),
#   ('neue', 'ADJA'),
#   ('Regierung', 'NN'),
#   ('noch', 'ADV'),
#   ('nicht', 'PTKNEG'),
#   ('herangetraut', 'VVPP'),
#   (',', '$,'),
#   ('obwohl', 'KOUS'),
#   ('eine', 'ART'),
#   ('durchgreifende', 'ADJA'),
#   ('wirtschaftliche', 'ADJA'),
#   ('Veränderung', 'NN'),
#   ('gleichermaßen', 'ADV'),
#   ('drastische', 'ADJA'),
#   ('wie', 'KOKOM'),
#   ('unpopuläre', 'ADJA'),
#   ('Schritte', 'NN'),
#   ('verlangt', 'VVFIN'),
#   ('.', '$.'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('Dabei', 'PROAV'),
#   ('geht', 'VVFIN'),
#   ('es', 'PPER'),
#   ('vor', 'APPR'),
#   ('allem', 'PIS'),
#   ('um', 'APPR'),
#   ('die', 'ART'),
#   ('Milliardenverluste', 'NN'),
#   ('produzierende', 'ADJA'),
#   ('verstaatlichte', 'ADJA'),
#   ('Industrie', 'NN'),
#   (',', '$,'),
#   ('die', 'PRELS'),
#   ('zugleich', 'ADV'),
#   ('der', 'ART'),
#   ('größte', 'ADJA'),
#   ('Arbeitgeber', 'NN'),
#   ('ist', 'VAFIN'),
#   ('.', '$.'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('Die', 'ART'),
#   ('mächtigen', 'ADJA'),
#   ('Gewerkschaften', 'NN'),
#   ('haben', 'VAFIN'),
#   ('bisher', 'ADV'),
#   ('verhindert', 'VVPP'),
#   (',', '$,'),
#   ('daß', 'KOUS'),
#   ('unrentable', 'ADJA'),
#   ('Firmen', 'NN'),
#   ('geschlossen', 'VVPP'),
#   ('oder', 'KON'),
#   ('privatisiert', 'VVPP'),
#   ('werden', 'VAFIN'),
#   ('.', '$.'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('Der', 'ART'),
#   ('zweite', 'ADJA'),
#   ('Punkt', 'NN'),
#   ('ist', 'VAFIN'),
#   ('die', 'ART'),
#   ('Kürzung', 'NN'),
#   ('der', 'ART'),
#   ('Subventionen', 'NN'),
#   (',', '$,'),
#   ('die', 'PRELS'),
#   ('mehr', 'PIAT'),
#   ('als', 'KOKOM'),
#   ('ein', 'ART'),
#   ('Zehntel', 'NN'),
#   ('der', 'ART'),
#   ('Staatsausgaben', 'NN'),
#   ('verschlingen', 'VVFIN'),
#   (',', '$,'),
#   ('und', 'KON'),
#   ('von', 'APPR'),
#   ('denen', 'PRELS'),
#   ('nicht', 'PTKNEG'),
#   ('etwa', 'ADV'),
#   ('die', 'ART'),
#   ('Ärmsten', 'NN'),
#   ('der', 'ART'),
#   ('Armen', 'NN'),
#   ('profitieren', 'VVFIN'),
#   ('.', '$.'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('Auf', 'APPR'),
#   ('der', 'ART'),
#   ('Dringlichkeitsliste', 'NN'),
#   ('steht', 'VVFIN'),
#   ('außerdem', 'ADV'),
#   ('die', 'ART'),
#   ('Reorganisation', 'NN'),
#   ('der', 'ART'),
#   ('personell', 'ADJD'),
#   ('überbesetzten', 'ADJA'),
#   (',', '$,'),
#   ('ineffizienten', 'ADJA'),
#   ('öffentlichen', 'ADJA'),
#   ('Banken', 'NN'),
#   ('und', 'KON'),
#   ('eine', 'ART'),
#   ('Reform', 'NN'),
#   ('des', 'ART'),
#   ('Steuersystems', 'NN'),
#   ('.', '$.'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('Nahrungsmittelsicherheit', 'NN'),
#   ('aber', 'ADV'),
#   ('ist', 'VAFIN'),
#   ('die', 'ART'),
#   ('erste', 'ADJA'),
#   ('Voraussetzung', 'NN'),
#   ('für', 'APPR'),
#   ('Fortschritt', 'NN'),
#   ('und', 'KON'),
#   ('Stabilität', 'NN'),
#   ('in', 'APPR'),
#   ('Indien', 'NE'),
#   ('.', '$.'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('Die', 'ART'),
#   ('gegenwärtige', 'ADJA'),
#   ('Dürre', 'NN'),
#   (',', '$,'),
#   ('die', 'PRELS'),
#   ('mehr', 'PIAT'),
#   ('als', 'KOKOM'),
#   ('100', 'CARD'),
#   ('Millionen', 'NN'),
#   ('Menschen', 'NN'),
#   ('trifft', 'VVFIN'),
#   (',', '$,'),
#   ('hat', 'VAFIN'),
#   ('den', 'ART'),
#   ('Reformern', 'NN'),
#   ('erschreckend', 'ADJD'),
#   ('deutlich', 'ADJD'),
#   ('gemacht', 'VVPP'),
#   (',', '$,'),
#   ('daß', 'KOUS'),
#   ('sie', 'PPER'),
#   ('diesen', 'PDAT'),
#   ('entscheidenden', 'ADJA'),
#   ('Aspekt', 'NN'),
#   ('bei', 'APPR'),
#   ('all', 'PIAT'),
#   ('ihren', 'PPOSAT'),
#   ('Strategien', 'NN'),
#   ('vergessen', 'VVPP'),
#   ('hatten', 'VAFIN'),
#   ('.', '$.'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('Die', 'ART'),
#   ('Getreideproduktion', 'NN'),
#   ('1992', 'CARD'),
#   ('wird', 'VAFIN'),
#   ('voraussichtlich', 'ADJD'),
#   ('zehn', 'CARD'),
#   ('Millionen', 'NN'),
#   ('Tonnen', 'NN'),
#   ('geringer', 'ADJD'),
#   ('ausfallen', 'VVINF'),
#   ('als', 'KOKOM'),
#   ('geplant', 'VVPP'),
#   (',', '$,'),
#   ('während', 'KOUS'),
#   ('gleichzeitig', 'ADJD'),
#   ('die', 'ART'),
#   ('Bevölkerung', 'NN'),
#   ('um', 'APPR'),
#   ('18', 'CARD'),
#   ('Millionen', 'NN'),
#   ('Menschen', 'NN'),
#   ('steigt', 'VVFIN'),
#   ('.', '$.'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('Die', 'ART'),
#   ('Dürre', 'NN'),
#   ('könnte', 'VMFIN'),
#   ('deshalb', 'PROAV'),
#   ('den', 'ART'),
#   ('gerade', 'ADV'),
#   ('beginnenden', 'ADJA'),
#   ('Aufschwung', 'NN'),
#   ('zu', 'APPR'),
#   ('einem', 'ART'),
#   ('jähen', 'ADJA'),
#   ('Ende', 'NN'),
#   ('bringen', 'VVINF'),
#   ('.', '$.'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('Für', 'APPR'),
#   ('Indien', 'NE'),
#   ('wäre', 'VAFIN'),
#   ('das', 'PDS'),
#   ('eine', 'ART'),
#   ('Tragödie', 'NN'),
#   ('.', '$.'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'), ('GABRIELE', 'NE'), ('VENZKY', 'NE'), ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('Wechselspiel', 'NN'),
#   ('von', 'APPR'),
#   ('Dramatisierung', 'NN'),
#   ('und', 'KON'),
#   ('Ignoranz', 'NN'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('Der', 'ART'),
#   ('Politologe', 'NN'),
#   ('Hans-Gerd', 'NE'),
#   ('Jaschke', 'NE'),
#   ('über', 'APPR'),
#   ('den', 'ART'),
#   ('hilflosen', 'ADJA'),
#   ('Umgang', 'NN'),
#   ('mit', 'APPR'),
#   ('Rechtsradikalen', 'NN'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('FR', 'NE'),
#   (':', '$.'),
#   ('Auf', 'APPR'),
#   ('die', 'ART'),
#   ('Wahlerfolge', 'NN'),
#   ('der', 'ART'),
#   ('rechtsradikalen', 'ADJA'),
#   ('Parteien', 'NN'),
#   ('haben', 'VAFIN'),
#   ('die', 'ART'),
#   ('Etablierten', 'NN'),
#   ('in', 'APPR'),
#   ('den', 'ART'),
#   ('Parlamenten', 'NN'),
#   ('und', 'KON'),
#   ('viele', 'PIAT'),
#   ('Medien', 'NN'),
#   ('bisher', 'ADV'),
#   ('mit', 'APPR'),
#   ('einer', 'ART'),
#   ('``', '$('),
#   ('Strategie', 'NN'),
#   ('gezielter', 'ADJA'),
#   ('Ignoranz', 'NN'),
#   ("''", '$('),
#   ('reagiert', 'VVPP'),
#   ('.', '$.'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('Was', 'PWS'),
#   ('bewirkt', 'VVFIN'),
#   ('Ihrer', 'PPOSAT'),
#   ('Ansicht', 'NN'),
#   ('nach', 'APPO'),
#   ('ein', 'ART'),
#   ('solches', 'PIAT'),
#   ('Verhalten', 'NN'),
#   ('?', '$.'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('Jaschke', 'NE'),
#   (':', '$.'),
#   ('Der', 'ART'),
#   ('Umgang', 'NN'),
#   ('mit', 'APPR'),
#   ('rechtsradikalen', 'ADJA'),
#   ('Parteien', 'NN'),
#   ('nach', 'APPR'),
#   ('dem', 'ART'),
#   ('Krieg', 'NN'),
#   ('war', 'VAFIN'),
#   ('immer', 'ADV'),
#   ('ein', 'ART'),
#   ('Wechselspiel', 'NN'),
#   ('zwischen', 'APPR'),
#   ('Integration', 'NN'),
#   (',', '$,'),
#   ('Dramatisierung', 'NN'),
#   ('und', 'KON'),
#   ('Ignoranz', 'NN'),
#   ('.', '$.'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('In', 'APPR'),
#   ('den', 'ART'),
#   ('60er', 'ADJA'),
#   ('Jahren', 'NN'),
#   ('hat', 'VAFIN'),
#   ('man', 'PIS'),
#   ('versucht', 'VVPP'),
#   (',', '$,'),
#   ('die', 'ART'),
#   ('NPD', 'NE'),
#   ('auszugrenzen', 'VVIZU'),
#   (',', '$,'),
#   ('zu', 'PTKZU'),
#   ('stigmatisieren', 'VVINF'),
#   (',', '$,'),
#   ('mit', 'APPR'),
#   ('guten', 'ADJA'),
#   ('Gründen', 'NN'),
#   (':', '$.'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('Unter', 'APPR'),
#   ('den', 'ART'),
#   ('Abgeordneten', 'NN'),
#   ('gab', 'VVFIN'),
#   ('es', 'PPER'),
#   ('ehemalige', 'ADJA'),
#   ('PGs', 'NN'),
#   (',', '$,'),
#   ('ehemalige', 'ADJA'),
#   ('Nationalsozialisten', 'NN'),
#   (',', '$,'),
#   ('und', 'KON'),
#   ('mit', 'APPR'),
#   ('denen', 'PRELS'),
#   ('setzt', 'VVFIN'),
#   ('man', 'PIS'),
#   ('sich', 'PRF'),
#   ('nicht', 'PTKNEG'),
#   ('zusammen', 'ADV'),
#   ('an', 'APPR'),
#   ('einen', 'ART'),
#   ('Tisch', 'NN'),
#   ('.', '$.'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('Ich', 'PPER'),
#   ('halte', 'VVFIN'),
#   ('das', 'ART'),
#   ('damalige', 'ADJA'),
#   ('Verhalten', 'NN'),
#   ('für', 'APPR'),
#   ('richtig', 'ADJD'),
#   (',', '$,'),
#   ('auch', 'KON'),
#   ('für', 'APPR'),
#   ('symbolisch', 'ADJD'),
#   ('angemessen', 'ADJD'),
#   ('.', '$.'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('Es', 'PPER'),
#   ('wäre', 'VAFIN'),
#   ('vergleichbar', 'ADJD'),
#   ('mit', 'APPR'),
#   ('der', 'ART'),
#   ('heutigen', 'ADJA'),
#   ('Situation', 'NN'),
#   (',', '$,'),
#   ('wenn', 'KOUS'),
#   ('man', 'PIS'),
#   ('sich', 'PRF'),
#   ('mit', 'APPR'),
#   ('höheren', 'ADJA'),
#   ('Chargen', 'NN'),
#   ('etwa', 'ADV'),
#   ('der', 'ART'),
#   ('Stasi', 'NN'),
#   ('zusammensetzen', 'VVINF'),
#   ('würde', 'VAFIN'),
#   ('.', '$.'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('Das', 'PDS'),
#   ('hielte', 'VVFIN'),
#   ('ich', 'PPER'),
#   ('für', 'APPR'),
#   ('moralisch', 'ADJD'),
#   ('außerordentlich', 'ADJD'),
#   ('fragwürdig', 'ADJD'),
#   ('.', '$.'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('Nur', 'ADV'),
#   (':', '$.'),
#   ('Sie', 'PPER'),
#   ('müssen', 'VMFIN'),
#   ('bedenken', 'VVINF'),
#   (',', '$,'),
#   ('daß', 'KOUS'),
#   ('die', 'ART'),
#   ('heutigen', 'ADJA'),
#   ('Abgeordneten', 'NN'),
#   ('der', 'ART'),
#   ('Rechtsaußenparteien', 'NN'),
#   ('biographisch', 'ADJD'),
#   ('weit', 'ADJD'),
#   ('entfernt', 'VVPP'),
#   ('sind', 'VAFIN'),
#   ('vom', 'APPRART'),
#   ('Dritten', 'ADJA'),
#   ('Reich', 'NN'),
#   (',', '$,'),
#   ('insofern', 'ADV'),
#   ('entfällt', 'VVFIN'),
#   ('die', 'ART'),
#   ('direkte', 'ADJA'),
#   ('symbolische', 'ADJA'),
#   ('Legitimation', 'NN'),
#   (',', '$,'),
#   ('sie', 'PPER'),
#   ('auszugrenzen', 'VVIZU'),
#   ('.', '$.'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('Und', 'KON'),
#   ('sie', 'PPER'),
#   ('müssen', 'VMFIN'),
#   ('bedenken', 'VVINF'),
#   (',', '$,'),
#   ('daß', 'KOUS'),
#   ('heute', 'ADV'),
#   ('die', 'ART'),
#   ('zugrundeliegenden', 'ADJA'),
#   ('Probleme', 'NN'),
#   (',', '$,'),
#   ('das', 'PDS'),
#   (',', '$,'),
#   ('was', 'PRELS'),
#   ('diese', 'PDAT'),
#   ('Parteien', 'NN'),
#   ('eigentlich', 'ADV'),
#   ('artikulieren', 'VVFIN'),
#   (',', '$,'),
#   ('sehr', 'ADV'),
#   ('viel', 'ADV'),
#   ('tiefer', 'ADJD'),
#   ('reichen', 'VVFIN'),
#   ('als', 'KOKOM'),
#   ('in', 'APPR'),
#   ('den', 'ART'),
#   ('50er', 'ADJA'),
#   ('und', 'KON'),
#   ('60er', 'ADJA'),
#   ('Jahren', 'NN'),
#   ('.', '$.'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('Sie', 'PPER'),
#   ('betreffen', 'VVFIN'),
#   ('vor', 'APPR'),
#   ('allem', 'PIS'),
#   ('das', 'ART'),
#   ('Phänomen', 'NN'),
#   ('sozialer', 'ADJA'),
#   ('Ungleichheit', 'NN'),
#   (',', '$,'),
#   ('vor', 'APPR'),
#   ('allem', 'PIS'),
#   ('in', 'APPR'),
#   ('den', 'ART'),
#   ('großstädtischen', 'ADJA'),
#   ('Ballungsräumen', 'NN'),
#   (';', '$.'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('und', 'KON'),
#   ('sie', 'PPER'),
#   ('reichen', 'VVFIN'),
#   ('hinein', 'PTKVZ'),
#   ('in', 'APPR'),
#   ('das', 'ART'),
#   ('Unverständnis', 'NN'),
#   ('über', 'APPR'),
#   ('den', 'ART'),
#   ('Problemkomplex', 'NN'),
#   ('multikulturelle', 'ADJA'),
#   ('Gesellschaft', 'NN'),
#   ('.', '$.'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('Das', 'PDS'),
#   ('sind', 'VAFIN'),
#   ('derart', 'ADV'),
#   ('tiefgreifende', 'ADJA'),
#   ('Strukturprobleme', 'NN'),
#   (',', '$,'),
#   ('die', 'PRELS'),
#   ('sich', 'PRF'),
#   ('überhaupt', 'ADV'),
#   ('nicht', 'PTKNEG'),
#   ('lösen', 'VVINF'),
#   ('lassen', 'VVFIN'),
#   ('etwa', 'ADV'),
#   ('durch', 'APPR'),
#   ('Veränderungen', 'NN'),
#   ('des', 'ART'),
#   ('Asylrechts', 'NN'),
#   ('-', '$('),
#   ('ich', 'PPER'),
#   ('halte', 'VVFIN'),
#   ('das', 'PDS'),
#   ('für', 'APPR'),
#   ('Kosmetik', 'NN'),
#   ('an', 'APPR'),
#   ('der', 'ART'),
#   ('Oberfläche', 'NN'),
#   ('.', '$.'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('Die', 'ART'),
#   ('rechtsradikalen', 'ADJA'),
#   ('Parteien', 'NN'),
#   ('und', 'KON'),
#   ('ihre', 'PPOSAT'),
#   ('Wählerbasis', 'NN'),
#   ('können', 'VMFIN'),
#   ('nur', 'ADV'),
#   ('effektiv', 'ADJD'),
#   ('bekämpft', 'VVPP'),
#   ('werden', 'VAINF'),
#   (',', '$,'),
#   ('wenn', 'KOUS'),
#   ('man', 'PIS'),
#   ('diese', 'PDAT'),
#   ('zugrundeliegenden', 'ADJA'),
#   ('Probleme', 'NN'),
#   ('so', 'ADV'),
#   ('anpackt', 'VVFIN'),
#   (',', '$,'),
#   ('daß', 'KOUS'),
#   ('es', 'PPER'),
#   ('die', 'ART'),
#   ('Mehrheit', 'NN'),
#   ('der', 'ART'),
# ...
#  [('< >', '<//s>'),
#   ('Augenzeugen', 'NN'),
#   ('sagen', 'VVFIN'),
#   ('dagegen', 'PROAV'),
#   (',', '$,'),
#   ('die', 'ART'),
#   ('Sicherheitskräfte', 'NN'),
#   ('stehen', 'VVFIN'),
#   ('dahinter', 'PROAV'),
#   ('.', '$.'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('De', 'NE'),
#   ('Klerk', 'NE'),
#   ('bestritt', 'VVFIN'),
#   ('erneut', 'ADJD'),
#   ('jede', 'PIAT'),
#   ('Beteiligung', 'NN'),
#   ('der', 'ART'),
#   ('Regierung', 'NN'),
#   ('an', 'APPR'),
#   ('den', 'ART'),
#   ('Gewaltakten', 'NN'),
#   (':', '$.'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('``', '$('),
#   ('Dieser', 'PDAT'),
#   ('Vorwurf', 'NN'),
#   ('bleibt', 'VVFIN'),
#   ('eine', 'ART'),
#   ('Lüge', 'NN'),
#   (',', '$,'),
#   ('egal', 'ADV'),
#   ('wie', 'KOKOM'),
#   ('oft', 'ADV'),
#   ('er', 'PPER'),
#   ('wiederholt', 'VVPP'),
#   ('wird', 'VAFIN'),
#   ('.', '$.'),
#   ("''", '$('),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('Nach', 'APPR'),
#   ('de', 'NE'),
#   ('Klerks', 'NE'),
#   ('Versprechungen', 'NN'),
#   ('sollen', 'VMFIN'),
#   ('außerdem', 'PROAV'),
#   ('die', 'ART'),
#   ('``', '$('),
#   ('Hostel', 'NE'),
#   ("''", '$('),
#   ('genannten', 'ADJA'),
#   ('Bastione', 'NN'),
#   ('der', 'ART'),
#   ("``Inkatha''-Kämpfer", 'NN'),
#   ('schnellstmöglich', 'ADJD'),
#   ('in', 'APPR'),
#   ('Familienwohnheime', 'NN'),
#   ('umgewandelt', 'VVPP'),
#   ('und', 'KON'),
#   ('ein', 'ART'),
#   ('generelles', 'ADJA'),
#   ('Verbot', 'NN'),
#   ('von', 'APPR'),
#   ('``', '$('),
#   ('traditionellen', 'ADJA'),
#   ('Waffen', 'NN'),
#   ("''", '$('),
#   ('erwogen', 'VVPP'),
#   ('werden', 'VAINF'),
#   ('.', '$.'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('Schließlich', 'ADV'),
#   ('scheint', 'VVFIN'),
#   ('sich', 'PRF'),
#   ('die', 'ART'),
#   ('Regierung', 'NN'),
#   ('auch', 'ADV'),
#   ('auf', 'APPR'),
#   ('jenem', 'PDAT'),
#   ('Feld', 'NN'),
#   ('zu', 'PTKZU'),
#   ('bewegen', 'VVINF'),
#   (',', '$,'),
#   ('auf', 'APPR'),
#   ('dem', 'PRELS'),
#   ('die', 'ART'),
#   ('Verhandlungen', 'NN'),
#   ('im', 'APPRART'),
#   ('Rahmen', 'NN'),
#   ('der', 'ART'),
#   ('``', '$('),
#   ('Konferenz', 'NN'),
#   ('für', 'APPR'),
#   ('ein', 'ART'),
#   ('demokratisches', 'ADJA'),
#   ('Südafrika', 'NE'),
#   ("''", '$('),
#   ('(', '$('),
#   ('Codesa', 'NE'),
#   (')', '$('),
#   ('ins', 'APPRART'),
#   ('Stocken', 'NN'),
#   ('geraten', 'VVPP'),
#   ('waren', 'VAFIN'),
#   (':', '$.'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('in', 'APPR'),
#   ('dem', 'ART'),
#   ('Antwortschreiben', 'NN'),
#   ('ist', 'VAFIN'),
#   ('davon', 'PROAV'),
#   ('die', 'ART'),
#   ('Rede', 'NN'),
#   (',', '$,'),
#   ('daß', 'KOUS'),
#   ('auch', 'ADV'),
#   ('eine', 'ART'),
#   ('zweite', 'ADJA'),
#   ('Parlamentskammer', 'NN'),
#   ('nach', 'APPR'),
#   ('dem', 'ART'),
#   ('Mehrheitsrecht', 'NN'),
#   ('besetzt', 'VVPP'),
#   ('werden', 'VAINF'),
#   ('sollte', 'VMFIN'),
#   ('.', '$.'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('Bislang', 'ADV'),
#   ('wollte', 'VMFIN'),
#   ('die', 'ART'),
#   ('Regierung', 'NN'),
#   ('jeder', 'PIAT'),
#   ('Partei', 'NN'),
#   (',', '$,'),
#   ('die', 'PRELS'),
#   ('eine', 'ART'),
#   ('bestimmte', 'ADJA'),
#   ('Prozentzahl', 'NN'),
#   ('erreicht', 'VVFIN'),
#   (',', '$,'),
#   ('im', 'APPRART'),
#   ('``', '$('),
#   ('Senat', 'NN'),
#   ("''", '$('),
#   ('dieselbe', 'ADJA'),
#   ('Anzahl', 'NN'),
#   ('von', 'APPR'),
#   ('Sitzen', 'NN'),
#   ('zuteilen', 'VVINF'),
#   (',', '$,'),
#   ('was', 'PRELS'),
#   ('gemeinsam', 'ADJD'),
#   ('mit', 'APPR'),
#   ('der', 'ART'),
#   ('Forderung', 'NN'),
#   ('nach', 'APPR'),
#   ('Dreiviertelmehrheiten', 'NN'),
#   ('einer', 'ART'),
#   ('Veto-Möglichkeit', 'NN'),
#   ('für', 'APPR'),
#   ('die', 'ART'),
#   ('weiße', 'ADJA'),
#   ('Bevölkerungsminderheit', 'NN'),
#   ('gleichgekommen', 'VVPP'),
#   ('wäre', 'VAFIN'),
#   ('.', '$.'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('Diplomaten', 'NN'),
#   ('blieben', 'VVFIN'),
#   ('allerdings', 'ADV'),
#   ('skeptisch', 'ADJD'),
#   (',', '$,'),
#   ('ob', 'KOUS'),
#   ('der', 'ART'),
#   ('nicht', 'PTKNEG'),
#   ('eindeutige', 'ADJA'),
#   ('Passus', 'NN'),
#   ('in', 'APPR'),
#   ('dem', 'ART'),
#   ('Brief', 'NN'),
#   ('tatsächlich', 'ADJD'),
#   ('den', 'ART'),
#   ('Durchbruch', 'NN'),
#   ('des', 'ART'),
#   ('Kabinetts', 'NN'),
#   ('de', 'NE'),
#   ('Klerk', 'NE'),
#   ('zu', 'APPR'),
#   ('demokratischen', 'ADJA'),
#   ('Werten', 'NN'),
#   ('westlichen', 'ADJA'),
#   ('Standards', 'NN'),
#   ('bedeutet', 'VVFIN'),
#   ('.', '$.'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('Tagestip', 'NN'),
#   (':', '$.'),
#   ('Zweifamilienhaus', 'NN'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('Bleistift', 'NN'),
#   ('spitzen', 'VVINF'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('Besitzer', 'NN'),
#   ('von', 'APPR'),
#   ('Zweifamilienhäusern', 'NN'),
#   (',', '$,'),
#   ('die', 'PRELS'),
#   ('vor', 'APPR'),
#   ('1987', 'CARD'),
#   ('gebaut', 'VVPP'),
#   ('oder', 'KON'),
#   ('gekauft', 'VVPP'),
#   ('haben', 'VAFIN'),
#   ('und', 'KON'),
#   ('noch', 'ADV'),
#   ('nach', 'APPR'),
#   ('``', '$('),
#   ('altem', 'ADJA'),
#   ("''", '$('),
#   ('Recht', 'NN'),
#   ('mit', 'APPR'),
#   ('dem', 'ART'),
#   ('Finanzamt', 'NN'),
#   ('abrechnen', 'VVFIN'),
#   (',', '$,'),
#   ('sollten', 'VMFIN'),
#   ('Jahr', 'NN'),
#   ('für', 'APPR'),
#   ('Jahr', 'NN'),
#   ('überlegen', 'VVINF'),
#   (',', '$,'),
#   ('ob', 'KOUS'),
#   ('sich', 'PRF'),
#   ('das', 'PDS'),
#   ('für', 'APPR'),
#   ('sie', 'PPER'),
#   ('noch', 'ADV'),
#   ('lohnt', 'VVFIN'),
#   ('.', '$.'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('Für', 'APPR'),
#   ('vor', 'APPR'),
#   ('1987', 'CARD'),
#   ('gebaute', 'ADJA'),
#   ('und', 'KON'),
#   ('gekaufte', 'ADJA'),
#   ('Zweifamilienhäuser', 'NN'),
#   ('setzt', 'VVFIN'),
#   ('der', 'ART'),
#   ('Fiskus', 'NN'),
#   ('Mieteinnahmen', 'NN'),
#   ('für', 'APPR'),
#   ('die', 'ART'),
#   ('ganze', 'ADJA'),
#   ('Wohnfläche', 'NN'),
#   ('an', 'PTKVZ'),
#   ('.', '$.'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('Das', 'PDS'),
#   ('bedeutet', 'VVFIN'),
#   (',', '$,'),
#   ('daß', 'KOUS'),
#   ('auch', 'ADV'),
#   ('für', 'APPR'),
#   ('den', 'ART'),
#   ('selbstgenutzten', 'ADJA'),
#   ('Teil', 'NN'),
#   ('des', 'ART'),
#   ('Heimes', 'NN'),
#   ('Miete', 'NN'),
#   ('angesetzt', 'VVPP'),
#   ('und', 'KON'),
#   ('davon', 'PROAV'),
#   ('Steuern', 'NN'),
#   ('berechnet', 'VVPP'),
#   ('werden', 'VAFIN'),
#   ('.', '$.'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('Im', 'APPRART'),
#   ('Gegenzug', 'NN'),
#   ('kann', 'VMFIN'),
#   ('der', 'ART'),
#   ('Besitzer', 'NN'),
#   ('sämtliche', 'PIAT'),
#   ('Kosten', 'NN'),
#   ('einschließlich', 'APPR'),
#   ('der', 'ART'),
#   ('Abschreibung', 'NN'),
#   ('vom', 'APPRART'),
#   ('gesamten', 'ADJA'),
#   ('Mietwert', 'NN'),
#   ('abziehen', 'VVINF'),
#   ('-', '$('),
#   ('unterstellt', 'VVPP'),
#   (',', '$,'),
#   ('daß', 'KOUS'),
#   ('er', 'PPER'),
#   ('für', 'APPR'),
#   ('den', 'ART'),
#   ('vermieteten', 'ADJA'),
#   ('Teil', 'NN'),
#   ('des', 'ART'),
#   ('Hauses', 'NN'),
#   ('wenigstens', 'ADV'),
#   ('50', 'CARD'),
#   ('Prozent', 'NN'),
#   ('der', 'ART'),
#   ('ortsüblichen', 'ADJA'),
#   ('Miete', 'NN'),
#   ('kassiert', 'VVFIN'),
#   ('.', '$.'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('Für', 'APPR'),
#   ('nach', 'APPR'),
#   ('1986', 'CARD'),
#   ('gebaute', 'ADJA'),
#   ('respektive', 'KON'),
#   ('gekaufte', 'ADJA'),
#   ('Häuser', 'NN'),
#   ('entfällt', 'VVFIN'),
#   ('der', 'ART'),
#   ('Ansatz', 'NN'),
#   ('eines', 'ART'),
#   ('Mietwertes', 'NN'),
#   ('für', 'APPR'),
#   ('die', 'ART'),
#   ('eigene', 'ADJA'),
#   ('Wohnung', 'NN'),
#   ('.', '$.'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('Besitzer', 'NN'),
#   ('älterer', 'ADJA'),
#   ('Häuser', 'NN'),
#   ('können', 'VMFIN'),
#   ('dieses', 'PDAT'),
#   ('Recht', 'NN'),
#   ('ebenfalls', 'ADV'),
#   ('für', 'APPR'),
#   ('sich', 'PRF'),
#   ('in', 'APPR'),
#   ('Anspruch', 'NN'),
#   ('nehmen', 'VVINF'),
#   ('-', '$('),
#   ('letztmals', 'ADV'),
#   ('für', 'APPR'),
#   ('1998', 'CARD'),
#   ('.', '$.'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('*', 'XY'),
#   ('Ist', 'VAFIN'),
#   ('der', 'ART'),
#   ('Mietwert', 'NN'),
#   ('des', 'ART'),
#   ('gesamten', 'ADJA'),
#   ('Hauses', 'NN'),
#   ('höher', 'ADJD'),
#   ('als', 'KOKOM'),
#   ('anfallende', 'ADJA'),
#   ('Kosten', 'NN'),
#   ('(', '$('),
#   ('Reparaturen', 'NN'),
#   (',', '$,'),
#   ('Instandhaltung', 'NN'),
#   (',', '$,'),
#   ('Hypothekenzinsen', 'NN'),
#   (',', '$,'),
#   ('Abschreibung', 'NN'),
#   (')', '$('),
#   ('und', 'KON'),
#   ('wird', 'VAFIN'),
#   ('sich', 'PRF'),
#   ('daran', 'PROAV'),
#   ('auch', 'ADV'),
#   ('nichts', 'PIS'),
#   ('ändern', 'VVINF'),
#   ('(', '$('),
#   ('weil', 'KOUS'),
#   ('etwa', 'ADV'),
#   ('die', 'ART'),
#   ('Hypotheken', 'NN'),
#   ('weitgegend', 'ADJD'),
#   ('abgetragen', 'VVPP'),
#   ('und', 'KON'),
#   ('größere', 'ADJA'),
#   ('Reparaturen', 'NN'),
#   ('nicht', 'PTKNEG'),
#   ('zu', 'PTKZU'),
#   ('erwarten', 'VVINF'),
#   ('sind', 'VAFIN'),
#   (')', '$('),
#   (',', '$,'),
#   ('dann', 'ADV'),
#   ('sollte', 'VMFIN'),
#   ('der', 'ART'),
#   ('Besitzer', 'NN'),
#   ('das', 'ART'),
#   ('neue', 'ADJA'),
#   ('Recht', 'NN'),
#   ('wählen', 'VVINF'),
#   ('.', '$.'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('Er', 'PPER'),
#   ('muß', 'VMFIN'),
#   ('dann', 'ADV'),
#   ('nur', 'ADV'),
#   ('noch', 'ADV'),
#   ('den', 'ART'),
#   ('vermieteten', 'ADJA'),
#   ('Teil', 'NN'),
#   ('des', 'ART'),
#   ('Hauses', 'NN'),
#   ('versteuern', 'VVINF'),
#   ('-', '$('),
#   ('kann', 'VMFIN'),
#   ('aber', 'ADV'),
#   ('auch', 'ADV'),
#   ('nur', 'ADV'),
#   ('die', 'ART'),
#   ('darauf', 'PROAV'),
#   ('entfallenden', 'ADJA'),
#   ('Kosten', 'NN'),
#   ('gegenrechnen', 'VVINF'),
#   ('.', '$.'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('*', 'XY'),
#   ('Sind', 'VAFIN'),
#   ('die', 'ART'),
#   ('Kosten', 'NN'),
#   ('für', 'APPR'),
#   ('das', 'ART'),
#   ('Haus', 'NN'),
#   ('so', 'ADV'),
#   ('hoch', 'ADJD'),
#   (',', '$,'),
#   ('daß', 'KOUS'),
#   ('sie', 'PPER'),
#   ('den', 'ART'),
#   ('Mietwert', 'NN'),
#   ('auf', 'APPR'),
#   ('viele', 'PIAT'),
#   ('Jahre', 'NN'),
#   ('oder', 'KON'),
#   ('auch', 'ADV'),
#   ('nur', 'ADV'),
#   ('auf', 'APPR'),
#   ('absehbare', 'ADJA'),
#   ('Zeit', 'NN'),
#   ('hin', 'APZR'),
#   ('übersteigen', 'VVFIN'),
#   (',', '$,'),
#   ('empfiehlt', 'VVFIN'),
#   ('es', 'PPER'),
#   ('sich', 'PRF'),
#   (',', '$,'),
#   ('am', 'APPRART'),
#   ('bisherigen', 'ADJA'),
#   ('Recht', 'NN'),
#   ('festzuhalten', 'VVIZU'),
#   ('.', '$.'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('Das', 'PDS'),
#   ('hilft', 'VVFIN'),
#   ('möglicherweise', 'ADV'),
#   ('bis', 'APPR'),
#   ('1998', 'CARD'),
#   ('Steuern', 'NN'),
#   ('sparen', 'VVINF'),
#   (',', '$,'),
#   ('weil', 'KOUS'),
#   ('der', 'ART'),
#   ('``', '$('),
#   ('Überschuß', 'NN'),
#   ('der', 'ART'),
#   ('Ausgaben', 'NN'),
#   ("''", '$('),
#   ('das', 'ART'),
#   ('steuerpflichtige', 'ADJA'),
#   ('Einkommen', 'NN'),
#   ('drückt', 'VVFIN'),
#   ('.', '$.'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('Der', 'ART'),
#   ('Hausbesitzer', 'NN'),
#   ('braucht', 'VVFIN'),
#   ('in', 'APPR'),
#   ('dem', 'ART'),
#   ('Falle', 'NN'),
#   ('nichts', 'PIS'),
#   ('zu', 'PTKZU'),
#   ('unternehmen', 'VVINF'),
#   ('.', '$.'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('*', 'XY'),
#   ('Wenn', 'KOUS'),
#   ('das', 'ART'),
#   ('Pendel', 'NN'),
#   ('zwischen', 'APPR'),
#   ('``', '$('),
#   ('Gewinn', 'NN'),
#   ("''", '$('),
#   ('und', 'KON'),
#   ('``', '$('),
#   ('Verlust', 'NN'),
#   ("''", '$('),
#   ('derzeit', 'ADV'),
#   ('zwar', 'ADV'),
#   ('trotz', 'APPR'),
#   ('des', 'ART'),
#   ('Mietansatzes', 'NN'),
#   ('für', 'APPR'),
#   ('die', 'ART'),
#   ('eigene', 'ADJA'),
#   ('Wohnung', 'NN'),
#   ('noch', 'ADV'),
#   ('in', 'APPR'),
#   ('Richtung', 'NN'),
#   ('``', '$('),
#   ('Steuerersparnis', 'NN'),
#   ("''", '$('),
#   ('ausschlägt', 'VVFIN'),
#   (',', '$,'),
#   ('dies', 'PDS'),
#   ('aber', 'ADV'),
#   ('etwa', 'ADV'),
#   ('wegen', 'APPR'),
#   ('sinkender', 'ADJA'),
#   ('Zinsaufwendungen', 'NN'),
#   ('bald', 'ADV'),
#   ('ins', 'APPRART'),
#   ('Gegenteil', 'NN'),
#   ('umschlagen', 'VVINF'),
#   ('kann', 'VMFIN'),
#   (',', '$,'),
#   ('kann', 'VMFIN'),
#   ('es', 'PPER'),
#   ('zunächst', 'ADV'),
#   ('beim', 'APPRART'),
#   ('bisherigen', 'ADJA'),
#   ('Recht', 'NN'),
#   ('bleiben', 'VVINF'),
#   ('.', '$.'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('Sobald', 'KOUS'),
#   ('die', 'ART'),
#   ('Mietansätze', 'NN'),
#   ('die', 'ART'),
#   ('Kosten', 'NN'),
#   ('übersteigen', 'VVFIN'),
#   (',', '$,'),
#   ('wird', 'VAFIN'),
#   ('aufs', 'APPRART'),
#   ('neue', 'ADJA'),
#   ('Recht', 'NN'),
#   ('umgestiegen', 'VVPP'),
#   ('.', '$.'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('Da', 'KOUS'),
#   ('dies', 'PDS'),
#   ('eine', 'ART'),
#   ('nicht', 'PTKNEG'),
#   ('wieder', 'ADV'),
#   ('zu', 'PTKZU'),
#   ('korrigierende', 'ADJA'),
#   ('Entscheidung', 'NN'),
#   ('ist', 'VAFIN'),
#   ('(', '$('),
#   ('Hessisches', 'ADJA'),
#   ('Finanzgericht', 'NN'),
#   ('AZ', 'NN'),
#   (':', '$.'),
#   ('2', 'CARD'),
#   ('K', 'XY'),
#   ('3188', 'CARD'),
#   ('/', '$('),
#   ('90', 'CARD'),
#   (')', '$('),
#   (',', '$,'),
#   ('heißt', 'VVFIN'),
#   ('es', 'PPER'),
#   ('bis', 'APPR'),
#   ('1998', 'CARD'),
#   (',', '$,'),
#   ('jährlich', 'ADJD'),
#   ('zu', 'PTKZU'),
#   ('überdenken', 'VVINF'),
#   (',', '$,'),
#   ('wann', 'PWAV'),
#   ('der', 'ART'),
#   ('Zeitpunkt', 'NN'),
#   ('dafür', 'PROAV'),
#   ('gekommen', 'VVPP'),
#   ('ist', 'VAFIN'),
#   (',', '$,'),
#   ('vom', 'APPRART'),
#   ('alten', 'ADJA'),
#   ('Recht', 'NN'),
#   ('Abschied', 'NN'),
#   ('zu', 'PTKZU'),
#   ('nehmen', 'VVINF'),
#   ('.', '$.'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'), ('bü', 'XY'), ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('Rabbi', 'NN'),
#   ('Tanenbaum', 'NE'),
#   ('ist', 'VAFIN'),
#   ('tot', 'ADJD'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('NEW', 'NE'),
#   ('YORK', 'NE'),
#   (',', '$,'),
#   ('5.', 'ADJA'),
#   ('Juli', 'NN'),
#   ('(', '$('),
#   ('AP', 'NE'),
#   (')', '$('),
#   ('.', '$.'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('Rabbi', 'NN'),
#   ('Marc', 'NE'),
#   ('Tanenbaum', 'NE'),
#   (',', '$,'),
#   ('der', 'PRELS'),
#   ('eine', 'ART'),
#   ('wichtige', 'ADJA'),
#   ('Rolle', 'NN'),
#   ('im', 'APPRART'),
#   ('Dialog', 'NN'),
#   ('zwischen', 'APPR'),
#   ('dem', 'ART'),
#   ('Vatikan', 'NE'),
#   ('und', 'KON'),
#   ('den', 'ART'),
#   ('Juden', 'NN'),
#   ('spielte', 'VVFIN'),
#   ('und', 'KON'),
#   ('bis', 'APPR'),
#   ('1989', 'CARD'),
#   ('Direktor', 'NN'),
#   ('für', 'APPR'),
#   ('internationale', 'ADJA'),
#   ('Beziehungen', 'NN'),
#   ('im', 'APPRART'),
#   ('American', 'NE'),
#   ('Jewish', 'NE'),
#   ('Committee', 'NE'),
#   ('war', 'VAFIN'),
#   (',', '$,'),
#   ('ist', 'VAFIN'),
#   ('im', 'APPRART'),
#   ('Alter', 'NN'),
#   ('von', 'APPR'),
#   ('66', 'CARD'),
#   ('Jahren', 'NN'),
#   ('gestorben', 'VVPP'),
#   ('.', '$.'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('Tanenbaum', 'NE'),
#   ('galt', 'VVFIN'),
#   ('als', 'APPR'),
#   ('ein', 'ART'),
#   ('führender', 'ADJA'),
#   ('Vertreter', 'NN'),
#   ('des', 'ART'),
#   ('US-Judentums', 'NN'),
#   ('und', 'KON'),
#   ('wurde', 'VAFIN'),
#   ('gelegentlich', 'ADJD'),
#   ('``', '$('),
#   ('Außenminister', 'NN'),
#   ('der', 'ART'),
#   ('Juden', 'NN'),
#   ("''", '$('),
#   ('genannt', 'VVPP'),
#   ('.', '$.'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('Als', 'APPR'),
#   ('einziger', 'ADJA'),
#   ('Jude', 'NN'),
#   ('nahm', 'VVFIN'),
#   ('Tanenbaum', 'NE'),
#   ('1965', 'CARD'),
#   ('am', 'APPRART'),
#   ('Zweiten', 'ADJA'),
#   ('Vatikanischen', 'ADJA'),
#   ('Konzil', 'NN'),
#   ('in', 'APPR'),
#   ('Rom', 'NE'),
#   ('teil', 'PTKVZ'),
#   ('.', '$.'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('Er', 'PPER'),
#   ('bemühte', 'VVFIN'),
#   ('sich', 'PRF'),
#   ('um', 'APPR'),
#   ('den', 'ART'),
#   ('Dialog', 'NN'),
#   ('mit', 'APPR'),
#   ('den', 'ART'),
#   ('christlichen', 'ADJA'),
#   ('Konfessionen', 'NN'),
#   ('.', '$.'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('Anschläge', 'NN'),
#   ('in', 'APPR'),
#   ('Nordspanien', 'NE'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('FUENTERRABIA', 'NE'),
#   (',', '$,'),
#   ('5.', 'ADJA'),
#   ('Juli', 'NN'),
#   ('(', '$('),
#   ('AP', 'NE'),
#   (')', '$('),
#   ('.', '$.'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('Bei', 'APPR'),
#   ('Sprengstoffanschlägen', 'NN'),
#   ('haben', 'VAFIN'),
#   ('am', 'APPRART'),
#   ('Samstag', 'NN'),
#   ('in', 'APPR'),
#   ('der', 'ART'),
#   ('nordspanischen', 'ADJA'),
#   ('Stadt', 'NN'),
#   ('Fuenterrabia', 'NE'),
#   ('Unbekannte', 'NN'),
#   ('sieben', 'CARD'),
#   ('Autos', 'NN'),
#   ('zerstört', 'VVPP'),
#   ('.', '$.'),
#   ('< >', '<//s>')],
#  [('< >', '<//s>'),
#   ('Wie', 'PWAV'),
#   ('die', 'ART'),
#   ('Behörden', 'NN'),
#   ('mitteilten', 'VVFIN'),
#   (',', '$,'),
#   ('waren', 'VAFIN'),
#   ('darunter', 'PROAV'),
#   ('drei', 'CARD'),
#   ('Fahrzeuge', 'NN'),
#   ('einer', 'ART'),
#   ('britischen', 'ADJA'),
#   ('Fernsehgesellschaft', 'NN'),
#   ('.', '$.'),
#   ('< >', '<//s>')],
#  ...]

# %%
# Klasse initialisieren
tagger = CRFTagger()

# Trainingsdaten laden
train_data = tagger.read_data("train.txt")

# Einmaliges Training (keine Epochen)
for sentence in train_data:
    words = [w for w, _ in sentence]
    tags = [t for _, t in sentence]
    tagger.update_weights(words, tags)

# Nach dem Training Parameter speichern
import pickle
with open("crf_model.pkl", "wb") as f:
    pickle.dump(tagger.weights, f)
